# %%
import itertools
import os, json, random
from pathlib import Path
from collections import defaultdict

from PIL import Image
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T
import torchvision.models as models
import torch.optim as optim
import matplotlib.pyplot as plt           # optional for sanity-check
import regex  # pip install regex  (needed for \X = Unicode grapheme)
import matplotlib.pyplot as plt
import torchvision.transforms.functional as F
from matplotlib import font_manager
from PIL import Image, ImageOps

# %%
"""
make_line_crops.py
────────────────────────────────────────────────────────────────────────
• Extracts line-level crops from PAGE-level images using word-box JSON.
• Normalises every crop to identical size (H=32 px, W=512 px).
• Builds the Sinhala grapheme-cluster charset and writes:
      ├─ <CROP_DIR>/labels.json   (crop_name  →  full line text)
      └─ <CROP_DIR>/chars.txt     (one cluster per line)
"""

import os, json, regex, math, random
from pathlib import Path
from collections import defaultdict

from PIL import Image, ImageOps, ImageFont, ImageDraw
import matplotlib.pyplot as plt
from matplotlib import font_manager

# ─────────────────── 0.  EDIT THESE PATHS  ─────────────────────────
PAGE_DIR = Path(r"D:\python\data\images")          # page-level images
ANN_FILE = Path(r"D:\python\data\json\labels.json")
CROP_DIR = Path(r"D:\python\data\line_crops")      # new crops + ckpts
CKPT_DIR = CROP_DIR / "checkpoints"

font_path = (
    r"C:/Users/ASUS/Downloads/Noto_Sans_Sinhala,Yuji_Mai/"
    r"Noto_Sans_Sinhala/NotoSansSinhala-VariableFont_wdth,wght.ttf"
)

# ─────────────────── 1.  ONE-OFF SET-UP  ───────────────────────────
font_manager.fontManager.addfont(font_path)
plt.rcParams["font.family"] = "Noto Sans Sinhala"

CROP_DIR.mkdir(parents=True, exist_ok=True)
CKPT_DIR.mkdir(exist_ok=True)

# ─────────────────── 2.  LOAD WORD-BOX JSON  ───────────────────────
with ANN_FILE.open(encoding="utf-8") as f:
    raw = json.load(f)           # list[dict] – {uid: [word,…]} per page

label_map   = {}                # crop_name → GT string
line_counts = defaultdict(int)

# ─────────────────── 3.  HELPER: GRAPHEME CLUSTER SPLIT ────────────
cluster_re = regex.compile(r"\X", flags=regex.UNICODE)
def get_clusters(s: str) -> list[str]:
    """Return extended grapheme clusters sans whitespace."""
    return [c for c in cluster_re.findall(s) if not c.isspace()]

# ─────────────────── 4.  HELPER: RESIZE + PAD 32×512  ──────────────
def resize_and_pad(img: Image.Image,
                   target_size=(32, 512),
                   fill=255) -> Image.Image:
    """
    Keep aspect ratio, resize by **height**, then pad on the right
    to `target_size` with colour `fill` (white for mode "L").
    """
    tgt_h, tgt_w = target_size
    w, h = img.size
    scale = tgt_h / h
    new_w = int(w * scale)
    img_rs = img.resize((new_w, tgt_h), Image.BILINEAR)

    # If width still too big crop centre-left; otherwise pad right.
    if new_w >= tgt_w:
        img_rs = img_rs.crop((0, 0, tgt_w, tgt_h))
        return img_rs
    else:
        pad_w = tgt_w - new_w
        padding = (0, 0, pad_w, 0)                # (left, top, right, bottom)
        return ImageOps.expand(img_rs, padding, fill=fill)

# ─────────────────── 5.  MAIN LOOP: PAGES → LINE CROPS  ────────────
pad_vert = 4            # vertical padding in original crop
pad_horz = 4            # horizontal padding

all_clusters: set[str] = set()

for entry in raw:                       # entry = {uid: [word,…]}
    for uid, words in entry.items():
        page_path = PAGE_DIR / f"image_{uid}.png"
        if not page_path.exists():
            print(f"⚠️  missing page {page_path}")
            continue

        # ── group words roughly by y-centre (‘lines’) ────────────
        lines = []
        for w in sorted(words, key=lambda w: w["y"]):
            cy = w["y"]
            for line in lines:
                if abs(cy - line["cy"]) < 15:           # ≈ one text line
                    line["words"].append(w)
                    line["cy"] = (line["cy"] + cy) / 2
                    break
            else:
                lines.append({"cy": cy, "words": [w]})

        # ── open page and iterate each detected line ─────────────
        page = Image.open(page_path).convert("L")
        W_page, H_page = page.size

        for idx, line in enumerate(lines):
            bxs, bys, bxe, bye = [], [], [], []
            for w in line["words"]:
                x, y = w["x"], w["y"]
                w_ = w.get("w", w.get("width",  0))
                h_ = w.get("h", w.get("height", 0))
                x1 = w.get("x1", x + w_)
                y1 = w.get("y1", y + h_)
                bxs.append(x); bys.append(y)
                bxe.append(x1); bye.append(y1)

            # Fallback if heights are missing
            if max(bye) == min(bys):
                est_line_h = int(H_page * 0.05)
                bye = [y + est_line_h for y in bys]

            x0 = max(min(bxs) - pad_horz, 0)
            y0 = max(min(bys) - pad_vert, 0)
            x1 = min(max(bxe) + pad_horz, W_page)
            y1 = min(max(bye) + pad_vert, H_page)

            raw_crop = page.crop((x0, y0, x1, y1))

            # NORMALISE CROP SIZE 32×512
            crop = resize_and_pad(raw_crop, target_size=(32, 512), fill=255)

            crop_name = f"image_{uid}_line{idx:02d}.png"
            crop.save(CROP_DIR / crop_name)

            sorted_words = sorted(line["words"], key=lambda w: w["x"])
            text = " ".join(w["text"] for w in sorted_words).strip()
            label_map[crop_name] = text
            line_counts[uid] += 1

            # Gather clusters for charset
            for w in sorted_words:
                all_clusters.update(get_clusters(w["text"]))

# ─────────────────── 6.  BUILD CHARSET + TABLES  ───────────────────
charset = sorted(all_clusters)
if " " not in charset:             # ensure space present
    charset.append(" ")

stoi = {c: i + 1 for i, c in enumerate(charset)}   # 0 = blank for CTC
itos = {i: c for c, i in stoi.items()}

# ─────────────────── 7.  STATS + SAVE TO DISK  ─────────────────────
print("Unique grapheme clusters:", len(charset))
print("✅ Saved", len(label_map), "line crops.")
print("Avg lines per page:",
      sum(line_counts.values()) / max(len(line_counts), 1))

# 7a.  chars.txt
vocab_path = CROP_DIR / "chars.txt"
with vocab_path.open("w", encoding="utf-8") as f:
    for cluster in charset:
        f.write(cluster + "\n")

# 7b.  labels.json
out_path = CROP_DIR / "labels.json"
with out_path.open("w", encoding="utf-8") as f:
    json.dump(label_map, f, ensure_ascii=False, indent=2)

print(f"chars.txt  → {vocab_path}")
print(f"labels.json→ {out_path}")
# Out:
# ⚠️  missing page D:\python\data\images\image_670194b5-4593-40fe-abd2-ae0e5fb80700.png
# ⚠️  missing page D:\python\data\images\image_e5b610ed-3182-4f13-806f-6703b7d70a77.png
# ⚠️  missing page D:\python\data\images\image_8b37e49a-e51e-4895-a66b-611353893213.png
# ⚠️  missing page D:\python\data\images\image_3c9951c2-a6f3-4bc7-82b7-45c2ec74a6d4.png
# ⚠️  missing page D:\python\data\images\image_20547e05-0bae-4f79-b7b4-b29080eadc74.png
# ⚠️  missing page D:\python\data\images\image_53096bc1-0c0f-4418-b417-3167bfebe962.png
# ⚠️  missing page D:\python\data\images\image_699bca2a-ca36-40a1-b0c1-107f5f01d519.png
# ⚠️  missing page D:\python\data\images\image_d96a0a39-0243-4582-b583-358b1b78d2ce.png
# ⚠️  missing page D:\python\data\images\image_b4dfe0f0-73a1-450e-a595-7cac023756a2.png
# ⚠️  missing page D:\python\data\images\image_7fa3004a-98cb-46f8-82de-7e46c81c655c.png
# ⚠️  missing page D:\python\data\images\image_dfc7563b-a265-40b0-b2f5-387beb63f620.png
# ⚠️  missing page D:\python\data\images\image_d59a13d7-349b-42e9-9da5-ca36d9e60a6d.png
# ⚠️  missing page D:\python\data\images\image_fe513680-6dd3-49ef-9ea3-00ba67525fc0.png
# ⚠️  missing page D:\python\data\images\image_3e015166-95e3-4348-8ef9-058993b5b1d1.png
# ⚠️  missing page D:\python\data\images\image_f36d9d08-3032-41a7-b332-4d4f87ef120b.png
# ⚠️  missing page D:\python\data\images\image_424a8ea7-b859-48f6-956e-65958222aad7.png
# ⚠️  missing page D:\python\data\images\image_e625bd12-3d8b-441c-a855-b20257811fec.png
# ⚠️  missing page D:\python\data\images\image_c950f6fd-f008-44a5-af84-0ff4c9fd7fe5.png
# ⚠️  missing page D:\python\data\images\image_d6366a60-ede1-4ce8-b40d-5ad4afc71d69.png
# ⚠️  missing page D:\python\data\images\image_33b1cdc7-3d15-40e2-b949-1202b016b9b1.png
# ⚠️  missing page D:\python\data\images\image_0a83e9db-7883-4397-9952-48fe7f047c4c.png
# ⚠️  missing page D:\python\data\images\image_eac34c43-91b6-4689-af33-f59e87fa1080.png
# ⚠️  missing page D:\python\data\images\image_35cbf8fb-c378-495d-aa1c-1feb9f13c428.png
# ⚠️  missing page D:\python\data\images\image_af937b70-58a4-4dff-b8e7-a457ca8f2403.png
# ⚠️  missing page D:\python\data\images\image_959badb2-79cf-4354-a508-269dabe6887b.png
# ⚠️  missing page D:\python\data\images\image_a37e3dcd-8777-4b44-8a7e-d932ad48a079.png
# ⚠️  missing page D:\python\data\images\image_ee48fe6a-3134-416b-8eb4-6bbea53aede0.png
# ⚠️  missing page D:\python\data\images\image_8b45a986-cb53-4f91-99e5-3fe8af4fc59c.png
# ⚠️  missing page D:\python\data\images\image_4002c78f-3d10-4aaa-8b98-e0d0459ae13b.png
# ⚠️  missing page D:\python\data\images\image_54598983-34b4-43dd-aa2d-4e1081200085.png
# ⚠️  missing page D:\python\data\images\image_fb25f418-db66-4a63-bd78-616ea73405d2.png
# ⚠️  missing page D:\python\data\images\image_e93d922c-3e47-4416-a465-0056c47db242.png
# ⚠️  missing page D:\python\data\images\image_10baa580-a6b3-439b-9ea6-e07352fe2b5a.png
# ⚠️  missing page D:\python\data\images\image_5fef0605-eb6b-4c95-92f1-77f26c0afa64.png
# ⚠️  missing page D:\python\data\images\image_2c4016af-3380-4a79-9c89-bf1efe5a8fba.png
# ⚠️  missing page D:\python\data\images\image_817e65ef-db55-4a18-8288-b44adaece2c5.png
# ⚠️  missing page D:\python\data\images\image_051f85c3-0bdd-433d-bb9d-0c532791e9ec.png
# ⚠️  missing page D:\python\data\images\image_a8eaab68-bcc5-4d8b-b645-098244ac5408.png
# ⚠️  missing page D:\python\data\images\image_9db66c54-f0f9-4635-8824-9016cdcdacb1.png
# ⚠️  missing page D:\python\data\images\image_7fad05e8-507a-4e91-a2ba-38d5cfec7f31.png
# ⚠️  missing page D:\python\data\images\image_d09004a1-840e-46a9-87d6-a2ac4ccc5262.png
# ⚠️  missing page D:\python\data\images\image_f59f873f-f43b-458e-8859-fc10873176de.png
# ⚠️  missing page D:\python\data\images\image_cd17a9df-6d5b-445a-a086-c52046ec4a99.png
# ⚠️  missing page D:\python\data\images\image_c6de1244-4ff1-4344-9ca0-7799f6f51956.png
# ⚠️  missing page D:\python\data\images\image_d6de43f4-9021-4bf6-bc72-5cd05c7f17ef.png
# ⚠️  missing page D:\python\data\images\image_fa250e60-46ec-467a-ac88-6162bfa6d974.png
# ⚠️  missing page D:\python\data\images\image_8b1e1f2d-72c5-4ad3-8c4c-4d76ba543571.png
# ⚠️  missing page D:\python\data\images\image_31c9e58b-cdb8-4991-90a8-03c03a0c769a.png
# ⚠️  missing page D:\python\data\images\image_f1f0735b-4891-46a7-b107-53bcb7d238d3.png
# ⚠️  missing page D:\python\data\images\image_4697db29-0278-4f5a-9065-03b91f9ecd5e.png
# ⚠️  missing page D:\python\data\images\image_6ea3f38c-8a7d-4d12-b9ab-2b491cfca7eb.png
# ⚠️  missing page D:\python\data\images\image_cf46dfda-adda-4071-adf0-c119d53315c3.png
# ⚠️  missing page D:\python\data\images\image_870f8d65-e906-46cc-b6ce-a3e8edae20c3.png
# ⚠️  missing page D:\python\data\images\image_59af44c6-7816-47ac-9805-d563387e7d1a.png
# ⚠️  missing page D:\python\data\images\image_dc7f6bd1-f264-4f8c-93a8-e716446e7d70.png
# ⚠️  missing page D:\python\data\images\image_595336ba-1d39-47ae-96cb-3f53786eda06.png
# ⚠️  missing page D:\python\data\images\image_c5f32352-a469-441a-9b91-db1258130643.png
# ⚠️  missing page D:\python\data\images\image_b281467b-250f-4b60-a4d5-1bea3062844f.png
# ⚠️  missing page D:\python\data\images\image_70055e11-c9dc-46e6-bd64-474d2fb160a2.png
# ⚠️  missing page D:\python\data\images\image_4ecceb30-96e4-4538-bd33-757e518c04bb.png
# ⚠️  missing page D:\python\data\images\image_38f58279-ad99-45e4-b91c-aab40de06e98.png
# ⚠️  missing page D:\python\data\images\image_1b397929-3654-4f80-8052-18f6aa33ee88.png
# ⚠️  missing page D:\python\data\images\image_a2e4529f-521e-47f6-b68c-d1b5fe9dfc1f.png
# ⚠️  missing page D:\python\data\images\image_9826bd74-5d8a-4bf4-b7e8-236ba4c5f10a.png
# ⚠️  missing page D:\python\data\images\image_41abcb7b-cabc-4e3e-9d1a-60856b2e4f98.png
# ⚠️  missing page D:\python\data\images\image_07964de7-df3d-4204-8b1a-476679f7b850.png
# ⚠️  missing page D:\python\data\images\image_16e64056-98df-4c64-8127-b8efc38bb3ab.png
# ⚠️  missing page D:\python\data\images\image_9b518f56-f95a-4884-a1fc-c3991f4e992f.png
# ⚠️  missing page D:\python\data\images\image_a1a232f4-704d-4416-bc42-52abb0b82b42.png
# ⚠️  missing page D:\python\data\images\image_22a38faf-f9df-4173-8a31-faae953d2a10.png
# ⚠️  missing page D:\python\data\images\image_2896d6e3-b8b7-4610-9852-4e684aa4b4e2.png
# ⚠️  missing page D:\python\data\images\image_4afde140-4107-4946-b226-e0f91721e42c.png
# ⚠️  missing page D:\python\data\images\image_c743532c-c2b3-450d-8b4e-e5576d7d352e.png
# ⚠️  missing page D:\python\data\images\image_8a434f56-f84e-46ad-9552-5ea68d6bd2e1.png
# ⚠️  missing page D:\python\data\images\image_c61b7c8d-32b5-4eb9-a210-f710c1ae004b.png
# ⚠️  missing page D:\python\data\images\image_aeab93fd-79ef-44d8-bba3-bf299edfd143.png
# ⚠️  missing page D:\python\data\images\image_31d56d41-250c-49f7-aedb-55adbe33ea34.png
# ⚠️  missing page D:\python\data\images\image_f5ceca31-381c-458b-b0df-c88b95558515.png
# ⚠️  missing page D:\python\data\images\image_77d79831-18bd-47e1-9123-2f646b99be9f.png
# ⚠️  missing page D:\python\data\images\image_13481652-fa3a-4d83-a6f4-d1e7a152c925.png
# ⚠️  missing page D:\python\data\images\image_b8818f1b-f5f6-4648-9cc4-998361b0c984.png
# ⚠️  missing page D:\python\data\images\image_68755ffb-067b-4349-8695-797cc0f708d3.png
# ⚠️  missing page D:\python\data\images\image_4bca733b-9a2f-41f6-9d83-c42a340d9480.png
# ⚠️  missing page D:\python\data\images\image_b083379d-e87d-4408-9321-eaa52400c10e.png
# ⚠️  missing page D:\python\data\images\image_1feefe3f-d8d5-4200-a169-85a12f4125ab.png
# ⚠️  missing page D:\python\data\images\image_2e353866-6977-4cd3-88f8-32e8b6f760e4.png
# ⚠️  missing page D:\python\data\images\image_26ba23b2-9fff-4a00-9eac-d9c678af25aa.png
# ⚠️  missing page D:\python\data\images\image_6313f6ce-ff9a-41ac-a500-0adcba1d2a34.png
# ⚠️  missing page D:\python\data\images\image_dd8d0926-0d9d-4c69-8d9c-e65ef7e8920e.png
# ⚠️  missing page D:\python\data\images\image_68bf1b39-179f-41b8-9151-8109f3f99bd9.png
# ⚠️  missing page D:\python\data\images\image_6205b737-8bef-4e0b-8ae3-70f6c9ef41c0.png
# ⚠️  missing page D:\python\data\images\image_3de3225b-dfdc-4d6f-9765-7a5c4e93524b.png
# ⚠️  missing page D:\python\data\images\image_fb567547-7db0-427b-a1d7-6fc3d6b5b2a6.png
# ⚠️  missing page D:\python\data\images\image_4587e04e-e598-452a-af96-4fc4d4f331e2.png
# ⚠️  missing page D:\python\data\images\image_1789f10b-5468-4e9a-b86b-be73d37f5242.png
# ⚠️  missing page D:\python\data\images\image_54005afb-0a5b-44f0-af47-e0bb39008a99.png
# ⚠️  missing page D:\python\data\images\image_f87c828e-1c7b-4e2a-9848-c7ebe0f25ea9.png
# ⚠️  missing page D:\python\data\images\image_2eda533c-fdaf-403f-9695-fbf38d728ff1.png
# ⚠️  missing page D:\python\data\images\image_bc929001-232b-4e7a-9660-6dc23adcf440.png
# ⚠️  missing page D:\python\data\images\image_472af458-5ef9-4289-9206-bcf918c07e69.png
# ⚠️  missing page D:\python\data\images\image_b8cc5acc-8f56-4930-96e4-844b185cb64e.png
# ⚠️  missing page D:\python\data\images\image_95b096c4-fec5-4bd6-b5b3-e2b8019be0dc.png
# ⚠️  missing page D:\python\data\images\image_e5fba9fd-6523-458b-a24a-819c92428587.png
# ⚠️  missing page D:\python\data\images\image_b3309472-e532-4dfb-8645-800dcdbab0f8.png
# ⚠️  missing page D:\python\data\images\image_7df22751-4936-436c-a479-509f6f3a88eb.png
# ⚠️  missing page D:\python\data\images\image_b5575835-4ff9-49b0-bc00-a029bd81d414.png
# ⚠️  missing page D:\python\data\images\image_94fb174a-7b18-4ef7-ada8-32d0c0274d97.png
# ⚠️  missing page D:\python\data\images\image_cb47b7c6-dc1f-4d98-8de7-bbdb8467b3f3.png
# ⚠️  missing page D:\python\data\images\image_f5573194-74e9-4aba-b7e2-798825cf4ab7.png
# ⚠️  missing page D:\python\data\images\image_672baf91-0b93-4528-8e08-1b0aad689c90.png
# ⚠️  missing page D:\python\data\images\image_18d5347e-47ec-4a7f-9ef4-a3b2b95bc8c4.png
# ⚠️  missing page D:\python\data\images\image_c228f84e-b1e4-4e07-a344-c159515be8c6.png
# ⚠️  missing page D:\python\data\images\image_e249ba1a-3242-4d61-af5b-395c98da3569.png
# ⚠️  missing page D:\python\data\images\image_4139fd8c-339a-46a7-90c6-bebca9f68232.png
# ⚠️  missing page D:\python\data\images\image_ff04ed30-e00c-4e4e-8931-21c20949fdb8.png
# ⚠️  missing page D:\python\data\images\image_f5e0ed2a-6cb9-4f86-b98a-fab26ed99133.png
# ⚠️  missing page D:\python\data\images\image_6c9d595b-4b94-46ff-9779-dc0177359121.png
# ⚠️  missing page D:\python\data\images\image_6fe6f936-5404-478a-882d-39a37554aa9f.png
# ⚠️  missing page D:\python\data\images\image_189a1400-7c2f-495e-a304-8e5288d9e4d2.png
# ⚠️  missing page D:\python\data\images\image_30803f0c-a348-4a32-a1ba-30310988e694.png
# ⚠️  missing page D:\python\data\images\image_0ba3ea53-ccb8-4e4b-ada9-37a11b88105c.png
# ⚠️  missing page D:\python\data\images\image_075d273b-6301-4daa-b7ac-d0e755a090fa.png
# ⚠️  missing page D:\python\data\images\image_3d02a3c0-0afa-4148-af73-ec3186c18d7d.png
# ⚠️  missing page D:\python\data\images\image_eaf97ad1-2a79-4267-9171-3a13954131c3.png
# ⚠️  missing page D:\python\data\images\image_4b9bb5a1-d986-4c48-ba80-38de0e1b95af.png
# ⚠️  missing page D:\python\data\images\image_13298c1e-5ebb-4982-921d-8dccf8ea1bd6.png
# ⚠️  missing page D:\python\data\images\image_cce825b5-8822-490f-adb6-a4b2512a530b.png
# ⚠️  missing page D:\python\data\images\image_96930375-1a8a-403c-bd94-1ac3ce0f5a00.png
# ⚠️  missing page D:\python\data\images\image_e036e35e-f135-4abb-8503-87fc7fc31e53.png
# ⚠️  missing page D:\python\data\images\image_fdd234c5-a479-4e24-a798-b7980f283682.png
# ⚠️  missing page D:\python\data\images\image_678fef88-1676-4822-b3f2-eb4b16df31ea.png
# ⚠️  missing page D:\python\data\images\image_c53d0bdf-32c1-432e-bc34-2543148ddb35.png
# ⚠️  missing page D:\python\data\images\image_0bf0971e-7da1-4357-82af-480b3cd5f8fe.png
# ⚠️  missing page D:\python\data\images\image_c15dbbdc-1111-48f2-b8bc-c69242c74d37.png
# ⚠️  missing page D:\python\data\images\image_e29c5912-527a-4eb3-9625-4388766b40b8.png
# ⚠️  missing page D:\python\data\images\image_c1646fdb-245a-4be5-96cb-38044b558e0e.png
# ⚠️  missing page D:\python\data\images\image_8dd3d1be-e455-4caa-b437-ae5ad5e6072d.png
# ⚠️  missing page D:\python\data\images\image_f21a8e93-587d-4ddb-981b-7f0a1436ad06.png
# ⚠️  missing page D:\python\data\images\image_b195c9d3-dfb2-466c-8337-22fefc0df842.png
# ⚠️  missing page D:\python\data\images\image_6923e023-1dc0-4cd2-9732-2a9b32b38a46.png
# ⚠️  missing page D:\python\data\images\image_7f984e26-ae12-4ab5-afed-3683d078c38e.png
# ⚠️  missing page D:\python\data\images\image_17eac748-5882-443c-8740-2d477857bbc7.png
# ⚠️  missing page D:\python\data\images\image_cc7bfcd3-6ece-4e0d-bc1e-3f6a63787626.png
# ⚠️  missing page D:\python\data\images\image_27af00c6-3fb3-42be-9f45-5e7afbadde52.png
# ⚠️  missing page D:\python\data\images\image_53cf4789-e4f0-4f7a-aa6e-c885535227c2.png
# ⚠️  missing page D:\python\data\images\image_fdf94bbc-2b4a-49c3-967d-d282887cdd93.png
# ⚠️  missing page D:\python\data\images\image_c09c48f4-adcb-43f3-8b6f-ac65cf5c7014.png
# ⚠️  missing page D:\python\data\images\image_25510f9d-691a-4a69-b24e-130cf93aa6bc.png
# ⚠️  missing page D:\python\data\images\image_bc13060f-bd55-4d89-8f3c-dd88009d3575.png
# ⚠️  missing page D:\python\data\images\image_53356f35-e636-41d5-bc12-eee91e237f6d.png
# ⚠️  missing page D:\python\data\images\image_7d85b191-e0d3-44b4-af2c-30941d1ec0f1.png
# ⚠️  missing page D:\python\data\images\image_03344c1b-2acc-4f2e-a9f6-b37a24e56e09.png
# ⚠️  missing page D:\python\data\images\image_e706f64e-866d-488d-ac45-8e5810693261.png
# ⚠️  missing page D:\python\data\images\image_89a849e9-be47-4f4e-9a50-4818273f49bb.png
# ⚠️  missing page D:\python\data\images\image_357964ae-1363-479d-a729-a468a3eba5fd.png
# ⚠️  missing page D:\python\data\images\image_e2b25d35-cb08-424d-9d51-4bfbd8a24f8d.png
# ⚠️  missing page D:\python\data\images\image_9bd7601e-bed2-48fe-bf4f-14001bb7fee7.png
# ⚠️  missing page D:\python\data\images\image_607a6ef0-8ad5-44e6-a1e5-b5feeacfd3d9.png
# ⚠️  missing page D:\python\data\images\image_e9a17f49-1a94-46c3-9ccd-8a7e69db2b11.png
# ⚠️  missing page D:\python\data\images\image_58c45c48-6d8e-4c4b-a367-5b4d8b745b51.png
# ⚠️  missing page D:\python\data\images\image_0ea40025-9cfa-47fd-97c4-6a35fd1a09bf.png
# ⚠️  missing page D:\python\data\images\image_cc6fb20f-7a34-4f9c-9ed1-4c2c927dc695.png
# ⚠️  missing page D:\python\data\images\image_7924c434-9af4-438d-9a46-187b414bba1a.png
# ⚠️  missing page D:\python\data\images\image_050847da-e36b-408f-876d-5266df3f43c3.png
# ⚠️  missing page D:\python\data\images\image_193bfea8-3a97-40a5-9d5e-16d0c601145a.png
# ⚠️  missing page D:\python\data\images\image_e6fcd7d4-fc35-4690-91fd-093229998835.png
# ⚠️  missing page D:\python\data\images\image_02b2e0b4-5fc6-404b-94d6-96b808442c24.png
# ⚠️  missing page D:\python\data\images\image_88a729e4-f4f4-4c63-b4b7-b6904a092434.png
# ⚠️  missing page D:\python\data\images\image_9c9a026c-8f2f-4fee-8775-428b73e48c78.png
# ⚠️  missing page D:\python\data\images\image_462f1ab6-4f02-4d0d-ab91-3d4eecad8d80.png
# ⚠️  missing page D:\python\data\images\image_ac49927b-5c60-4744-8267-1607d940c359.png
# ⚠️  missing page D:\python\data\images\image_2bf1aed9-ed31-4b36-a26b-a61d79020ae8.png
# ⚠️  missing page D:\python\data\images\image_3f7c451c-11b2-42bb-a425-9bd4c96e4682.png
# ⚠️  missing page D:\python\data\images\image_3925ff71-b0ab-441a-8244-5ee80bdcabfb.png
# ⚠️  missing page D:\python\data\images\image_d9685360-0840-4f80-8a9a-36ee079a7010.png
# ⚠️  missing page D:\python\data\images\image_b99d9c7c-dc8a-420a-a8b2-c971b7ce49ff.png
# ⚠️  missing page D:\python\data\images\image_d4c64834-7e1e-47cc-aef5-82d33c10a82f.png
# ⚠️  missing page D:\python\data\images\image_d799e70b-45bd-4ac9-ba29-134231bbf13e.png
# ⚠️  missing page D:\python\data\images\image_f6bbcfc7-74de-44d5-aba0-e631670601cd.png
# ⚠️  missing page D:\python\data\images\image_76dd744c-a97f-420a-8c84-9ac91cc0fdb8.png
# ⚠️  missing page D:\python\data\images\image_01b71618-02de-4859-a3d7-26b73fb8ef71.png
# ⚠️  missing page D:\python\data\images\image_728e3577-69cf-41b3-977c-343b5308f712.png
# ⚠️  missing page D:\python\data\images\image_ffb996ad-8605-4f17-8404-e55d65a3b780.png
# ⚠️  missing page D:\python\data\images\image_1a8dead2-9627-4e34-ac65-039479658d3e.png
# ⚠️  missing page D:\python\data\images\image_da134b41-1a13-42d9-8601-ff64be500dcf.png
# ⚠️  missing page D:\python\data\images\image_f9d667b2-e0a4-4c73-b294-b26211d086c4.png
# ⚠️  missing page D:\python\data\images\image_1bf59157-a61a-4b7a-9bd8-ed9662583da4.png
# ⚠️  missing page D:\python\data\images\image_d6ada772-c788-4fc5-b8c6-bcb6eafb84f2.png
# ⚠️  missing page D:\python\data\images\image_0998352c-15ac-425c-a768-39649e22cd20.png
# ⚠️  missing page D:\python\data\images\image_3340ade9-7379-498e-a0bc-1a60ab8a76e0.png
# ⚠️  missing page D:\python\data\images\image_6c44a71b-2c2b-4682-a86c-3d74f0a3f843.png
# ⚠️  missing page D:\python\data\images\image_ee636678-80e2-438c-8f7b-5a6b2b44510f.png
# ⚠️  missing page D:\python\data\images\image_7430762b-bcd9-4acd-9c27-4ca5ec6f0d2f.png
# ⚠️  missing page D:\python\data\images\image_07b0b685-4ea8-4ede-b189-fd1d9baa0d8c.png
# ⚠️  missing page D:\python\data\images\image_cb99e669-85c6-42bf-992a-c7a3610f4aac.png
# ⚠️  missing page D:\python\data\images\image_dc3c3569-fc86-471e-b498-49324078c1a9.png
# ⚠️  missing page D:\python\data\images\image_053fc275-cf17-440a-83ed-bb263ca37156.png
# ⚠️  missing page D:\python\data\images\image_defd4860-98f1-4843-a0ee-9183dafde64e.png
# ⚠️  missing page D:\python\data\images\image_b469e3eb-1d1e-47b1-b42f-ca389e52f59d.png
# ⚠️  missing page D:\python\data\images\image_66563595-274a-491e-8857-067c8db9e332.png
# ⚠️  missing page D:\python\data\images\image_9dce59e6-1046-4829-95fa-102ae32c1f7e.png
# ⚠️  missing page D:\python\data\images\image_cac60229-b47b-42c5-af16-a1b9c5b7bbec.png
# ⚠️  missing page D:\python\data\images\image_7f72b250-ff2f-4626-8f5c-2de7a4e3af11.png
# ⚠️  missing page D:\python\data\images\image_b6cb96c4-6dbb-4442-a4b2-8d8d1785cdea.png
# ⚠️  missing page D:\python\data\images\image_97e9d974-c22c-489a-b2bd-173d2d23d3cf.png
# ⚠️  missing page D:\python\data\images\image_732308d9-a39c-45be-b7db-00ba07ad0403.png
# ⚠️  missing page D:\python\data\images\image_18d114ff-d6bf-4f36-9591-29f80bb5eb24.png
# ⚠️  missing page D:\python\data\images\image_f2a08cfc-2e74-47c3-8d6b-83b873b1e93d.png
# ⚠️  missing page D:\python\data\images\image_53d30d0d-ddc7-4cea-b732-f8e5552b9da9.png
# ⚠️  missing page D:\python\data\images\image_51016ea9-6cae-43d5-b7e1-1e3dd5a79404.png
# ⚠️  missing page D:\python\data\images\image_a409efb6-36a7-4ca0-a204-b32c0bdea4a9.png
# ⚠️  missing page D:\python\data\images\image_8423df76-21ab-43f8-a005-085bd878f131.png
# ⚠️  missing page D:\python\data\images\image_4a7fbe34-be43-47d7-a8e4-6b3c23704f19.png
# ⚠️  missing page D:\python\data\images\image_ddbcf802-b2b5-4adc-abd6-94c9b601b41a.png
# ⚠️  missing page D:\python\data\images\image_42d482f9-d8c9-4289-acfd-c1b1961b1837.png
# ⚠️  missing page D:\python\data\images\image_1f3b621e-e307-4c7a-9636-41fa015a3f12.png
# ⚠️  missing page D:\python\data\images\image_eb0f4020-b87e-4176-835d-a5da8cf71fae.png
# ⚠️  missing page D:\python\data\images\image_a98342f0-ff1c-4872-ae3c-a4bc97a110e2.png
# ⚠️  missing page D:\python\data\images\image_2e024787-c2ba-4d3d-8b88-1b901598242e.png
# ⚠️  missing page D:\python\data\images\image_22d9d440-7fd5-4084-aa74-d1c2914a9bd9.png
# ⚠️  missing page D:\python\data\images\image_672341eb-2c4e-49ff-84fa-e74227aedf8a.png
# ⚠️  missing page D:\python\data\images\image_caa8a938-ed4b-4a17-adea-5051deb4d476.png
# ⚠️  missing page D:\python\data\images\image_31a8693a-c0db-4016-a5d7-73a8c3c51dfe.png
# ⚠️  missing page D:\python\data\images\image_09467f2e-36ae-42e0-8272-0a7b5e30b2f8.png
# ⚠️  missing page D:\python\data\images\image_f49e170d-be26-4901-ae70-47666818155a.png
# ⚠️  missing page D:\python\data\images\image_eea3d741-721a-4120-b5c1-715901fb9410.png
# ⚠️  missing page D:\python\data\images\image_5e31c8a9-6cdb-4a6f-93a5-30c24cd057fb.png
# ⚠️  missing page D:\python\data\images\image_3748e6e1-8f55-4098-b31c-0d7684972cbe.png
# ⚠️  missing page D:\python\data\images\image_888fff0a-4a18-4bfc-8a6c-4ab14465d061.png
# ⚠️  missing page D:\python\data\images\image_f0f24000-4465-48a5-8850-3be4087dee1a.png
# ⚠️  missing page D:\python\data\images\image_c0e838e4-de64-42e2-907f-cbb578ddb6a1.png
# ⚠️  missing page D:\python\data\images\image_d606bdf5-f231-4de9-a752-94c9dd4b38d2.png
# ⚠️  missing page D:\python\data\images\image_063597f4-0e4c-4c6c-b7b0-a9f16f280663.png
# ⚠️  missing page D:\python\data\images\image_4e572d39-f167-45c8-be3e-143cc43d5f08.png
# ⚠️  missing page D:\python\data\images\image_bcf44493-f18a-41e4-b15b-256d6a37d522.png
# ⚠️  missing page D:\python\data\images\image_c6c7500b-c6a6-4a42-9d52-5a2da4677a81.png
# ⚠️  missing page D:\python\data\images\image_ac661f2e-5742-4073-929d-4bc0b2cae81b.png
# ⚠️  missing page D:\python\data\images\image_694dee54-f9db-4eaa-b18b-aba49bf113f3.png
# ⚠️  missing page D:\python\data\images\image_562a94b1-e194-4d3f-8606-a809f21b7837.png
# ⚠️  missing page D:\python\data\images\image_b7d60ccf-0854-41cf-a2c8-9dc91c9f4b9e.png
# ⚠️  missing page D:\python\data\images\image_891f999d-bb9f-44ac-9427-365d26dd2b0d.png
# ⚠️  missing page D:\python\data\images\image_92350181-57ef-4579-88cc-107419fc254b.png
# ⚠️  missing page D:\python\data\images\image_5c73dc9e-876c-4e25-bc1a-f47e2f3d8a3e.png
# ⚠️  missing page D:\python\data\images\image_39803b33-234d-42de-9010-3ff16946c80f.png
# ⚠️  missing page D:\python\data\images\image_2ea6cc4b-33a7-4105-8430-f5fb0d7261f5.png
# ⚠️  missing page D:\python\data\images\image_7bbb72ce-9f8c-4ce4-9833-2f98df63cbcc.png
# ⚠️  missing page D:\python\data\images\image_5daa8cea-21d6-49b3-be5b-4f211633a122.png
# ⚠️  missing page D:\python\data\images\image_57bc4f21-fc6c-4016-8b91-a8ab5729415d.png
# ⚠️  missing page D:\python\data\images\image_a271a618-86cc-4a62-bfbe-f198e4828d5d.png
# ⚠️  missing page D:\python\data\images\image_f3b81d88-0d29-4690-abcd-9a7cb89bcf6c.png
# ⚠️  missing page D:\python\data\images\image_8c6d242d-26a6-4d8f-92c2-5dd8c7e3519f.png
# ⚠️  missing page D:\python\data\images\image_d6c0ae71-7324-4e48-8f92-c1dca0dba4f6.png
# ⚠️  missing page D:\python\data\images\image_08f207d8-619e-4a4d-97ef-a9734acffb3b.png
# ⚠️  missing page D:\python\data\images\image_83060512-b835-473c-bd2f-5af8f503c464.png
# ⚠️  missing page D:\python\data\images\image_7909fc37-09fa-45e3-902d-3afc39fb3b19.png
# ⚠️  missing page D:\python\data\images\image_db1b1594-da9e-4f4c-8292-f925da372e63.png
# ⚠️  missing page D:\python\data\images\image_ca8e9d19-072c-4177-8bb5-aa67b2845cbd.png
# ⚠️  missing page D:\python\data\images\image_cfa65b53-b87a-4adc-9687-93fbec0121b3.png
# ⚠️  missing page D:\python\data\images\image_0507288c-b37d-4976-abe6-146e59cced35.png
# ⚠️  missing page D:\python\data\images\image_42f35f57-a494-48ba-afcb-fc686918fdeb.png
# ⚠️  missing page D:\python\data\images\image_116ed53e-ae7a-4b5e-b771-aed0036ec3e2.png
# ⚠️  missing page D:\python\data\images\image_775632a4-a93f-400c-abae-7b9053f895cb.png
# ⚠️  missing page D:\python\data\images\image_40dae232-f49c-4f9d-a6b8-d34f3a2a3cc5.png
# ⚠️  missing page D:\python\data\images\image_14d91ded-c877-465c-a41a-ffb0e193303d.png
# ⚠️  missing page D:\python\data\images\image_0f88025c-7541-4d64-b90a-0855594dbbc9.png
# ⚠️  missing page D:\python\data\images\image_bc5a2621-8eb5-4b56-93b4-30c514739e63.png
# ⚠️  missing page D:\python\data\images\image_961df8f7-8bbd-4149-9569-7a7c48050145.png
# ⚠️  missing page D:\python\data\images\image_2ef5235f-daaf-418e-95df-b0151bcdaefb.png
# ⚠️  missing page D:\python\data\images\image_952f3dfd-70b4-4e97-aaf3-cb2926e855d4.png
# ⚠️  missing page D:\python\data\images\image_6d87468b-3480-41c3-b36d-28a67afefe34.png
# ⚠️  missing page D:\python\data\images\image_7e655934-a6c6-4623-b7fc-b818a52efdc6.png
# ⚠️  missing page D:\python\data\images\image_2de50d6d-984c-4d20-83bc-d5f6230633e4.png
# ⚠️  missing page D:\python\data\images\image_14ca8099-41bc-49e4-a749-e319d7ad6bf9.png
# ⚠️  missing page D:\python\data\images\image_be5708ec-a671-434d-8c24-afa14a1c70e8.png
# ⚠️  missing page D:\python\data\images\image_ce4d81bd-650d-4686-8d8e-1e2b5dd81f9c.png
# ⚠️  missing page D:\python\data\images\image_56f3cd5a-b310-4cfb-b5c8-7057912f0575.png
# ⚠️  missing page D:\python\data\images\image_e6cb5707-d9c3-4692-b82c-10895ab6b791.png
# ⚠️  missing page D:\python\data\images\image_768e882d-5737-48e1-8072-dc4e8a872e9e.png
# ⚠️  missing page D:\python\data\images\image_530a515e-2088-4298-be69-fc25298550ae.png
# ⚠️  missing page D:\python\data\images\image_802c8295-fc77-4135-93fd-4e694722d50e.png
# ⚠️  missing page D:\python\data\images\image_6a273b80-8d4d-4465-aeb3-98e4f1f10797.png
# ⚠️  missing page D:\python\data\images\image_25870d80-9c48-455b-8780-98b4712069a2.png
# ⚠️  missing page D:\python\data\images\image_2cc51098-1bdc-49df-bcc1-b848c36683e2.png
# ⚠️  missing page D:\python\data\images\image_c54e8240-e592-403b-b584-5c6e2094f8c6.png
# ⚠️  missing page D:\python\data\images\image_264d11d0-6c99-4191-b902-60cc9ab83aa6.png
# ⚠️  missing page D:\python\data\images\image_354e6f58-e65d-4260-a229-9c900e8275b6.png
# ⚠️  missing page D:\python\data\images\image_ea2d9b02-f086-4593-9ca9-8f7254a24f72.png
# ⚠️  missing page D:\python\data\images\image_b8ce0491-af34-4c18-bf4e-89bd283864ab.png
# ⚠️  missing page D:\python\data\images\image_40ada29a-b3f9-48d3-93ce-4a5131da78b3.png
# ⚠️  missing page D:\python\data\images\image_2b1ee829-aa4b-4bf7-a49d-f54b55b93662.png
# ⚠️  missing page D:\python\data\images\image_0422c54a-7f25-4796-b6d4-54561f1ba8fd.png
# ⚠️  missing page D:\python\data\images\image_1f3e703e-f7b0-4e70-8c5e-110603f902ba.png
# ⚠️  missing page D:\python\data\images\image_f4b13149-70c8-4d69-90b5-487b038cb1f2.png
# ⚠️  missing page D:\python\data\images\image_79c09f08-9c56-443c-97bd-cabdba99b81c.png
# ⚠️  missing page D:\python\data\images\image_d7af24e0-409f-4890-af95-111dd7fb15fc.png
# ⚠️  missing page D:\python\data\images\image_bae2569e-4780-4fa5-a34a-f5b1836c15f1.png
# ⚠️  missing page D:\python\data\images\image_858d3436-2bf4-4e83-bf0c-a18bf775f272.png
# ⚠️  missing page D:\python\data\images\image_cfe048be-cece-4f2c-b462-c54366f64b8e.png
# ⚠️  missing page D:\python\data\images\image_aadc0924-de5c-498f-b19f-58637e52f9e8.png
# ⚠️  missing page D:\python\data\images\image_6ca7fd06-4794-4ee9-bb5b-96d50f709e07.png
# ⚠️  missing page D:\python\data\images\image_5f079945-0505-4d57-ab09-fa44ed2aa4fb.png
# ⚠️  missing page D:\python\data\images\image_14918384-3d02-4bcd-a4cf-fd11c7875116.png
# ⚠️  missing page D:\python\data\images\image_1c089d9f-42b1-4af7-9845-3d125486a717.png
# ⚠️  missing page D:\python\data\images\image_abd425a5-eb30-4895-9667-20acb9e9c00d.png
# ⚠️  missing page D:\python\data\images\image_70cafc4d-723f-4c9d-b5a4-a158b5d15ab8.png
# ⚠️  missing page D:\python\data\images\image_29964ae2-672a-4cba-8529-82c29241838d.png
# ⚠️  missing page D:\python\data\images\image_fad53921-61cb-4a3f-a64d-fd767cb51718.png
# ⚠️  missing page D:\python\data\images\image_67bbb79c-6938-4183-b513-a8b202a65d04.png
# ⚠️  missing page D:\python\data\images\image_ab48dca2-9d44-4332-a4ee-39082fc63fe0.png
# ⚠️  missing page D:\python\data\images\image_2c216007-0048-4b93-9650-bbf08e2388fd.png
# ⚠️  missing page D:\python\data\images\image_1db70b9c-f7f9-46f0-8431-94d8e8f0b094.png
# ⚠️  missing page D:\python\data\images\image_ddb83546-5737-479f-9bb9-ba52a6779a3c.png
# ⚠️  missing page D:\python\data\images\image_86453fed-6620-4606-a240-18aca1e12fff.png
# ⚠️  missing page D:\python\data\images\image_ccb9797e-e6ef-4e8b-9b62-26dee174b3ea.png
# ⚠️  missing page D:\python\data\images\image_406933f0-8d5b-417e-802d-a0e45c0f2bba.png
# ⚠️  missing page D:\python\data\images\image_81a9d1da-4c1c-42f8-bbfc-5f84b91f105f.png
# ⚠️  missing page D:\python\data\images\image_4ae854cd-6520-4c57-b7f5-e4935a976547.png
# ⚠️  missing page D:\python\data\images\image_5a594070-99ed-4cd3-a206-f3aed4419c1a.png
# ⚠️  missing page D:\python\data\images\image_b576e68b-598c-4d9a-862e-fbefaad8ffaa.png
# ⚠️  missing page D:\python\data\images\image_4e5dde24-0375-4fa1-96c5-787c40513765.png
# ⚠️  missing page D:\python\data\images\image_49112473-17e8-4890-9121-6c792e5c4250.png
# ⚠️  missing page D:\python\data\images\image_68f412d4-806d-4057-b71d-e89d940829ba.png
# ⚠️  missing page D:\python\data\images\image_a5620c49-d943-408c-8c48-9b95b377497c.png
# ⚠️  missing page D:\python\data\images\image_a05fbb4b-66eb-471d-b458-a979f60acfb0.png
# ⚠️  missing page D:\python\data\images\image_fc585236-b03c-49e3-91fc-a954b9a26405.png
# ⚠️  missing page D:\python\data\images\image_6a98ece4-1711-48a0-bd2d-780041c7bfda.png
# ⚠️  missing page D:\python\data\images\image_269df871-a7cc-4932-b8a2-3a6c10150f8f.png
# ⚠️  missing page D:\python\data\images\image_cdd62873-c252-4a72-a028-41b46b1b40ec.png
# ⚠️  missing page D:\python\data\images\image_10ba40a1-7210-4701-8110-0aba5de4b206.png
# ⚠️  missing page D:\python\data\images\image_e3c66fd4-9cca-400c-9c96-5a5b0769f945.png
# ⚠️  missing page D:\python\data\images\image_4e5718b5-6c26-479c-a2d8-c85ca0dc774c.png
# ⚠️  missing page D:\python\data\images\image_0c5d8a9a-4929-4849-8bba-1a8df4f8dd88.png
# ⚠️  missing page D:\python\data\images\image_c4dcae5f-135c-4b50-be97-b11c6bec91d4.png
# ⚠️  missing page D:\python\data\images\image_5dfeecc4-7901-40ce-92c0-6385a7a26fae.png
# ⚠️  missing page D:\python\data\images\image_010046f5-2c1d-4b9a-86c1-0146e25e47b2.png
# ⚠️  missing page D:\python\data\images\image_018172f5-e751-42d5-a80e-502f0db4edac.png
# ⚠️  missing page D:\python\data\images\image_91d66a6c-daab-4157-9c54-e6e182d41265.png
# ⚠️  missing page D:\python\data\images\image_3a877ff4-6269-40e8-bbea-f35c59cdb52a.png
# ⚠️  missing page D:\python\data\images\image_9d63a287-bff5-4585-a0be-564e58ebc096.png
# ⚠️  missing page D:\python\data\images\image_1da642b1-30a1-4f23-a6c6-0d4dd119e493.png
# ⚠️  missing page D:\python\data\images\image_bc224368-3b5e-44a3-b06f-cd07c0d93775.png
# ⚠️  missing page D:\python\data\images\image_d66537d8-f594-430d-ae67-827f8eccf406.png
# ⚠️  missing page D:\python\data\images\image_01452e7f-b413-433b-bac8-77433fbb8127.png
# ⚠️  missing page D:\python\data\images\image_118fe888-7049-4114-a2ac-62a8dbfcda22.png
# ⚠️  missing page D:\python\data\images\image_efb84af7-a822-4ce9-9cea-d2712cc12a3b.png
# ⚠️  missing page D:\python\data\images\image_68c8b515-c8e8-491f-86ac-7d5f05bd3ebf.png
# ⚠️  missing page D:\python\data\images\image_3cb75f96-1400-4adc-a78a-f57b1833a685.png
# ⚠️  missing page D:\python\data\images\image_19a81d0a-0f0c-45ad-af45-d7809b4602b1.png
# ⚠️  missing page D:\python\data\images\image_5b647247-b00a-43ad-854b-77d9a24e6a54.png
# ⚠️  missing page D:\python\data\images\image_7838b75d-9efa-468a-a40d-092c44ae10ad.png
# ⚠️  missing page D:\python\data\images\image_be98dc84-4b3e-434d-a9c8-fd5737471b4b.png
# ⚠️  missing page D:\python\data\images\image_fb97cc06-9c33-4f2f-ad57-b491713ee2b7.png
# ⚠️  missing page D:\python\data\images\image_5fd401a2-3b2f-496d-abe8-febd7e28c804.png
# ⚠️  missing page D:\python\data\images\image_74068067-3bcf-4291-a001-0ddf2cea5493.png
# ⚠️  missing page D:\python\data\images\image_afaf4ad7-3190-4347-876c-2822268efb41.png
# ⚠️  missing page D:\python\data\images\image_7c88b57e-4968-47d9-ab83-b4b5a1921512.png
# ⚠️  missing page D:\python\data\images\image_4fadeea8-b225-450c-a642-0ae0ffb006fd.png
# ⚠️  missing page D:\python\data\images\image_a8332fa7-7f9d-4849-bed4-e274f160f3ae.png
# ⚠️  missing page D:\python\data\images\image_6a09fc70-ecd0-4349-b467-3797387dff6e.png
# ⚠️  missing page D:\python\data\images\image_adac2e81-468f-4d92-bb38-cbee41f33cdd.png
# ⚠️  missing page D:\python\data\images\image_0c973780-1a5f-4894-ac9c-51f54bd160ed.png
# ⚠️  missing page D:\python\data\images\image_976327b8-b76b-4498-aed2-ade72e6252a0.png
# ⚠️  missing page D:\python\data\images\image_78486ab3-c17b-45d7-bedc-452f48c1a545.png
# ⚠️  missing page D:\python\data\images\image_121d28e8-3baf-4b94-a5a1-e8f4224ab6bb.png
# ⚠️  missing page D:\python\data\images\image_3168e06b-25b3-4907-8362-1014644a29d5.png
# ⚠️  missing page D:\python\data\images\image_e8febaea-224c-484d-8640-7ab7a6ac1c63.png
# ⚠️  missing page D:\python\data\images\image_619d7769-affb-472f-814a-6b36756b0db2.png
# ⚠️  missing page D:\python\data\images\image_1c50cb2c-66e0-4644-929c-56b9c6d0857e.png
# ⚠️  missing page D:\python\data\images\image_95b9f887-69f8-4a04-a4cc-8af97b05b2ee.png
# ⚠️  missing page D:\python\data\images\image_30ac63b7-0cf3-4ccf-a349-3dc0343dc2b3.png
# ⚠️  missing page D:\python\data\images\image_483a9a62-0fed-422c-8ba8-9fb2b6f7e19d.png
# ⚠️  missing page D:\python\data\images\image_88c54efd-dbaf-421a-b8ce-870b436d7da6.png
# ⚠️  missing page D:\python\data\images\image_9cefd4b0-96dd-4ee1-87ba-8275c41f9d2a.png
# ⚠️  missing page D:\python\data\images\image_01be26bc-e81b-4a3c-8624-e60d1387fb95.png
# ⚠️  missing page D:\python\data\images\image_18eee9dc-90ea-4db7-9f03-0e6592f74346.png
# ⚠️  missing page D:\python\data\images\image_2ec9df70-028c-448b-afe0-27bee9a5790f.png
# ⚠️  missing page D:\python\data\images\image_ff82bc6b-81c1-4876-a5ac-a8dc901aa6a1.png
# ⚠️  missing page D:\python\data\images\image_41af6c77-bdba-416a-8640-5e484ba2f4bd.png
# ⚠️  missing page D:\python\data\images\image_cd484f01-dc7b-4b00-97d1-98de29ac5914.png
# ⚠️  missing page D:\python\data\images\image_c5e72889-1b2a-480d-a1ab-7d458c32d6b5.png
# ⚠️  missing page D:\python\data\images\image_90c9463e-0732-4333-a162-c537a095fb8a.png
# ⚠️  missing page D:\python\data\images\image_46c2e994-133b-405f-b76e-ff5ef7aad8db.png
# ⚠️  missing page D:\python\data\images\image_4de4c41c-b5b4-4e1a-b08c-459243985a51.png
# ⚠️  missing page D:\python\data\images\image_d5a9078a-e7ce-4070-b289-34c06d298842.png
# ⚠️  missing page D:\python\data\images\image_0c108cb2-3d7f-44f4-aad1-32af9b99cfe8.png
# ⚠️  missing page D:\python\data\images\image_ffea2f42-f732-4a4c-ad20-b1a6c5f3a3f6.png
# ⚠️  missing page D:\python\data\images\image_89e73092-0346-44e5-8ea3-c794494f69fa.png
# ⚠️  missing page D:\python\data\images\image_a25b0988-1b0e-4d4c-b1ae-474c0e21b6b8.png
# ⚠️  missing page D:\python\data\images\image_f5c1bd0c-f7bf-45ba-b222-b489e4413b24.png
# ⚠️  missing page D:\python\data\images\image_8fccc5a3-e675-4e45-aa59-d63780abfa80.png
# ⚠️  missing page D:\python\data\images\image_1909fa45-9623-4d86-a940-7bc948269324.png
# ⚠️  missing page D:\python\data\images\image_51747136-2b00-46dc-95f7-93e310828ccf.png
# ⚠️  missing page D:\python\data\images\image_51e14f0b-f735-43cc-bf02-3729b232585f.png
# ⚠️  missing page D:\python\data\images\image_b413b3b7-3ae0-4a33-aaff-8b4df6b190d7.png
# ⚠️  missing page D:\python\data\images\image_a9958120-81ea-4e36-973e-b27fe55c05de.png
# ⚠️  missing page D:\python\data\images\image_3a5c0228-dfd4-470f-b525-d7181d56793e.png
# ⚠️  missing page D:\python\data\images\image_5b2b89a9-be3d-4f23-a4f3-7e465b9759a0.png
# ⚠️  missing page D:\python\data\images\image_6dad2a70-2ebe-44e1-9579-81ff67e48353.png
# ⚠️  missing page D:\python\data\images\image_b30ce085-1631-4449-9c5b-3c2e788361cb.png
# ⚠️  missing page D:\python\data\images\image_2d50d9b5-c8ea-4cc2-82ea-6da9b791c45a.png
# ⚠️  missing page D:\python\data\images\image_7ade378e-a02a-4d8e-a851-a4631772f138.png
# ⚠️  missing page D:\python\data\images\image_9c730a93-fc29-47c2-97d7-35c59e9e52a9.png
# ⚠️  missing page D:\python\data\images\image_39e89dec-c520-4a0b-97b8-0c660d46c120.png
# ⚠️  missing page D:\python\data\images\image_74463edc-59f7-4853-99f2-47bcb14795f2.png
# ⚠️  missing page D:\python\data\images\image_abafc2ac-8436-493a-a45f-767add118c58.png
# ⚠️  missing page D:\python\data\images\image_ffa5e516-5cbe-4f68-91c7-cf6cd494489c.png
# ⚠️  missing page D:\python\data\images\image_bb507002-15a2-48e2-b6ae-3319e64e2b78.png
# ⚠️  missing page D:\python\data\images\image_2be299ac-e95a-46b0-ad0b-d238671418ee.png
# ⚠️  missing page D:\python\data\images\image_5db4df3e-4e4f-4b85-a31e-2fac6d68d775.png
# ⚠️  missing page D:\python\data\images\image_61d7c99a-afb0-411f-949b-569e31dd719e.png
# ⚠️  missing page D:\python\data\images\image_48fc5c63-5e4a-40ae-bebb-9bdefe15f50b.png
# ⚠️  missing page D:\python\data\images\image_4ccf2559-c24a-480f-b3d2-3560e5b8dbbb.png
# ⚠️  missing page D:\python\data\images\image_b8c798c3-0f5e-47a6-9309-909bb3b086bd.png
# ⚠️  missing page D:\python\data\images\image_a0f7893d-232a-42c4-9155-ee076e85e317.png
# ⚠️  missing page D:\python\data\images\image_807c1fce-872b-48bd-8b7a-eeaf25cb74ab.png
# ⚠️  missing page D:\python\data\images\image_85263162-5cb7-4b61-bb39-0fb73ca6e167.png
# ⚠️  missing page D:\python\data\images\image_6d92c889-fd60-4f6e-9140-e596d658cc91.png
# ⚠️  missing page D:\python\data\images\image_ade4efd1-a9e5-4c67-ad23-e0e8d7b0d9fd.png
# ⚠️  missing page D:\python\data\images\image_27819e53-ba2e-4bb9-b5ef-3b448dcf13b3.png
# ⚠️  missing page D:\python\data\images\image_4a49071c-9257-45ac-b515-a3664edda091.png
# ⚠️  missing page D:\python\data\images\image_f07de48a-b987-44ad-91cd-d58e78ce39c9.png
# ⚠️  missing page D:\python\data\images\image_6c308006-644b-48cc-8051-372166986526.png
# ⚠️  missing page D:\python\data\images\image_2cefb4b3-f7ed-4c7b-ba8b-c42606e0439d.png
# ⚠️  missing page D:\python\data\images\image_8c61e2cb-9d7c-4dee-8e60-631db822f1e8.png
# ⚠️  missing page D:\python\data\images\image_c6390be0-4935-4dd9-a4c3-7d8608192dd5.png
# ⚠️  missing page D:\python\data\images\image_f5a27b05-42ce-462a-93b9-dce562ec0d76.png
# ⚠️  missing page D:\python\data\images\image_45ab2049-10e7-4a41-8a20-e0177d2ba12d.png
# ⚠️  missing page D:\python\data\images\image_834dc81e-8ad4-476e-966a-561cb4bd2866.png
# ⚠️  missing page D:\python\data\images\image_e7be8d93-12a9-4f1f-ad6a-9507971dc4c4.png
# ⚠️  missing page D:\python\data\images\image_f588e555-e7b2-486a-ae10-d1bcfc4fdf65.png
# ⚠️  missing page D:\python\data\images\image_6daeb9ae-0332-48ee-8c78-a47e48c5d135.png
# ⚠️  missing page D:\python\data\images\image_34cbef00-677d-4480-ae79-5e09aa1740e3.png
# ⚠️  missing page D:\python\data\images\image_74bd6403-5ed4-48e9-ac21-4a572dd624f9.png
# ⚠️  missing page D:\python\data\images\image_44543129-8169-435e-8554-2c3dce86615f.png
# ⚠️  missing page D:\python\data\images\image_a996006c-f021-4d13-9dda-443c3a60c367.png
# ⚠️  missing page D:\python\data\images\image_994e59a9-c5e3-47a4-86b9-0e82263cf64c.png
# ⚠️  missing page D:\python\data\images\image_5585fe6e-9773-4aaf-824c-9ffa62c53edd.png
# ⚠️  missing page D:\python\data\images\image_bb2eaacf-edd8-441f-9f14-c003ce29d454.png
# ⚠️  missing page D:\python\data\images\image_3043205b-7f18-4da7-bff1-be7434d58bfa.png
# ⚠️  missing page D:\python\data\images\image_d276efaa-b6ed-4a6d-942e-6bcf2048dc89.png
# ⚠️  missing page D:\python\data\images\image_fd9e3382-ffcc-4809-ac60-65c88dea7cfc.png
# ⚠️  missing page D:\python\data\images\image_4a5dfeba-3ce9-42b1-9460-6dcd0fb35cde.png
# ⚠️  missing page D:\python\data\images\image_485c68f1-a020-4ca0-8075-38ab45e86e4a.png
# ⚠️  missing page D:\python\data\images\image_81fbd289-95cb-41e6-960e-a69a6f3fe97e.png
# ⚠️  missing page D:\python\data\images\image_c39967b2-7e32-4aa1-b1e9-d29e7477d1d4.png
# ⚠️  missing page D:\python\data\images\image_c1788e07-1b2a-44c8-910a-198124c7fb32.png
# ⚠️  missing page D:\python\data\images\image_c06d79bd-be3b-4f16-85a6-c5f320831781.png
# ⚠️  missing page D:\python\data\images\image_7a5a899e-fb8e-4ad3-b5b1-49d8a36cfa96.png
# ⚠️  missing page D:\python\data\images\image_29b7190f-1488-4944-9fe0-46abd8f0d3af.png
# ⚠️  missing page D:\python\data\images\image_f33e5eac-cb02-46c0-ac30-0a8e9c9a5d06.png
# ⚠️  missing page D:\python\data\images\image_c8736155-592b-4144-aaa1-f9a11729bf36.png
# ⚠️  missing page D:\python\data\images\image_a3090fdc-b4f8-4e96-a2f8-317fb456023f.png
# ⚠️  missing page D:\python\data\images\image_a2f40531-7753-460c-869c-1d575a0c478f.png
# ⚠️  missing page D:\python\data\images\image_c31f8555-62e4-4726-a493-e1c73c5af801.png
# ⚠️  missing page D:\python\data\images\image_6a32fb45-21cf-4237-9d7e-435f7ae93a3e.png
# ⚠️  missing page D:\python\data\images\image_7f757204-f83e-4d15-ac44-33b4afa9fc4c.png
# ⚠️  missing page D:\python\data\images\image_56abc8f3-7803-4cb6-bf8f-a22fae8a67ce.png
# ⚠️  missing page D:\python\data\images\image_4c8f0767-3a03-411e-83ac-f8344fb8f0c7.png
# ⚠️  missing page D:\python\data\images\image_c8bb7709-a76a-4388-91c7-8fc16ffaacb9.png
# ⚠️  missing page D:\python\data\images\image_1edc1cc7-c759-466b-85bc-2255d10588db.png
# ⚠️  missing page D:\python\data\images\image_a3c05aff-9dac-4a26-8953-31eedf3d1d49.png
# ⚠️  missing page D:\python\data\images\image_6c4b77d8-2621-4dff-9f1a-dbf110907e67.png
# ⚠️  missing page D:\python\data\images\image_00edf6db-a5e1-408c-b651-d9f7ec838fde.png
# ⚠️  missing page D:\python\data\images\image_283ca05c-a0a4-4f84-99f7-f7caaf707db3.png
# ⚠️  missing page D:\python\data\images\image_250b2ee9-4009-417a-8147-270e6e7ed9a0.png
# ⚠️  missing page D:\python\data\images\image_78d67c12-9014-4e0c-925a-cdb694080df9.png
# ⚠️  missing page D:\python\data\images\image_7b0e9b58-7ed2-4d38-86fa-29e5b8e31b41.png
# ⚠️  missing page D:\python\data\images\image_776331ca-2850-44d1-b7ef-344c7a56fdb5.png
# ⚠️  missing page D:\python\data\images\image_6baeb4a4-44f8-4a68-a89c-2db437aaff08.png
# ⚠️  missing page D:\python\data\images\image_15f5447c-7dd6-41e4-89bd-c04a4e535431.png
# ⚠️  missing page D:\python\data\images\image_b2731741-5c5a-4900-b399-ee30855e59f9.png
# ⚠️  missing page D:\python\data\images\image_be1d4698-1da3-4a6a-9bb9-8af4fe9306bf.png
# ⚠️  missing page D:\python\data\images\image_1e8f416a-6919-4e5c-89eb-cd60caddd5ab.png
# ⚠️  missing page D:\python\data\images\image_2d02078f-1204-431d-980d-931f2990227b.png
# ⚠️  missing page D:\python\data\images\image_958f4c51-6d96-41be-b8b2-33bef8adb183.png
# ⚠️  missing page D:\python\data\images\image_8fd99a6b-8503-44d7-a03e-d884b3054952.png
# ⚠️  missing page D:\python\data\images\image_537f1c24-f633-4488-89ec-633eb8688143.png
# ⚠️  missing page D:\python\data\images\image_85894f58-7197-4b59-8fb8-0dbcb3b1b22e.png
# ⚠️  missing page D:\python\data\images\image_eea3ae3e-54c0-4f0e-a925-72ea6aa513ef.png
# ⚠️  missing page D:\python\data\images\image_bb712618-8925-467c-bd48-09dfc70c9eec.png
# ⚠️  missing page D:\python\data\images\image_1c64cb38-ccdb-4b95-bdd8-a816d946ce84.png
# ⚠️  missing page D:\python\data\images\image_c6570876-5bdd-4bb6-b2f0-aab47cacb943.png
# ⚠️  missing page D:\python\data\images\image_fef11176-28bb-4d2d-8ff2-efda7ec87ce1.png
# ⚠️  missing page D:\python\data\images\image_6b559fa3-54aa-4416-9433-73767a96a568.png
# ⚠️  missing page D:\python\data\images\image_b85795ae-1272-441a-960a-0beef67a6096.png
# ⚠️  missing page D:\python\data\images\image_73dfcfff-798e-4adc-b808-f46be1f61012.png
# ⚠️  missing page D:\python\data\images\image_5d93726a-4941-42ce-853e-3e3b14d1fd8f.png
# ⚠️  missing page D:\python\data\images\image_d40e8184-fc4b-4c50-b6f5-77e24b80dab9.png
# ⚠️  missing page D:\python\data\images\image_a29e6c3e-dfeb-46c0-bea6-7f1e1be24bf9.png
# ⚠️  missing page D:\python\data\images\image_11df88d6-9fe3-4a61-a36f-0f46c4bc9aaa.png
# ⚠️  missing page D:\python\data\images\image_bb32046a-e699-45b3-b85f-ef9349f0f5be.png
# ⚠️  missing page D:\python\data\images\image_43dc762c-0d68-4aa4-995e-6485b23e2d33.png
# ⚠️  missing page D:\python\data\images\image_5e0d2e2d-9a66-42f1-8873-770f6e4c133f.png
# ⚠️  missing page D:\python\data\images\image_9d521958-ffdd-43a4-a4b2-456546318947.png
# ⚠️  missing page D:\python\data\images\image_3580e9a8-4af9-40f5-95a0-fd895df45182.png
# ⚠️  missing page D:\python\data\images\image_199ece83-3f5f-468b-8a16-a7d9c5e3d4da.png
# ⚠️  missing page D:\python\data\images\image_2ecd8b2f-0660-4d61-9db9-4dadf4dc1899.png
# ⚠️  missing page D:\python\data\images\image_1b0dd2c3-3386-4f8f-996b-4c1f250b2266.png
# ⚠️  missing page D:\python\data\images\image_af504a82-3fc1-49bb-8e64-c95339aa7e33.png
# ⚠️  missing page D:\python\data\images\image_f9fa73d5-2210-41be-ab4e-e2e2860a9a0f.png
# ⚠️  missing page D:\python\data\images\image_ec2630b6-c982-49d0-b6d7-3e40a97b4787.png
# ⚠️  missing page D:\python\data\images\image_eb306f88-1a13-40f4-becf-10880358982f.png
# ⚠️  missing page D:\python\data\images\image_23f22252-de14-4000-a622-e1994850fba2.png
# ⚠️  missing page D:\python\data\images\image_c6f1204d-0918-441c-98b6-5480c9dd6692.png
# ⚠️  missing page D:\python\data\images\image_4ca4adbf-cb64-4050-b5ad-d4d9c59a703b.png
# ⚠️  missing page D:\python\data\images\image_fae73fb9-4fe7-413d-9165-9bf33c79f2a6.png
# ⚠️  missing page D:\python\data\images\image_d8c8e45c-f101-4f90-8847-066046523843.png
# ⚠️  missing page D:\python\data\images\image_a1ff171a-3e8a-4dfe-87a7-a26e956b81e9.png
# ⚠️  missing page D:\python\data\images\image_4001c735-5140-4e1b-bc62-a6a6c14cb7df.png
# ⚠️  missing page D:\python\data\images\image_1d9bfc96-9132-4d4b-bca7-e47eac4e6411.png
# ⚠️  missing page D:\python\data\images\image_62b3f001-4b78-40d2-920e-ad8130ed1a64.png
# ⚠️  missing page D:\python\data\images\image_9e8bb054-3001-4eab-8599-f2cfe58b30f5.png
# ⚠️  missing page D:\python\data\images\image_30fd3025-7973-4634-80df-eab7c31df49d.png
# ⚠️  missing page D:\python\data\images\image_e8621520-e742-4012-9442-31fc98cff819.png
# ⚠️  missing page D:\python\data\images\image_46871682-7305-4a34-bc22-7d6bfd18d086.png
# ⚠️  missing page D:\python\data\images\image_2d264ba1-31a3-496b-a4d4-b57213cad2fe.png
# ⚠️  missing page D:\python\data\images\image_28e5711e-5569-4e0d-b458-ec105ebeb72e.png
# ⚠️  missing page D:\python\data\images\image_3ee1a243-2065-40c7-bc8f-97b9e926097f.png
# ⚠️  missing page D:\python\data\images\image_2210e452-8ece-4a93-9bdd-7e3e609e3a73.png
# ⚠️  missing page D:\python\data\images\image_47a3af45-637b-4914-bc6d-b19dfa66642a.png
# ⚠️  missing page D:\python\data\images\image_5bd8560c-8150-4d29-8198-5c48ce316201.png
# ⚠️  missing page D:\python\data\images\image_8e119b50-9a97-4c9f-9e11-69faddebd163.png
# ⚠️  missing page D:\python\data\images\image_21951187-a292-4c58-94db-d707abadedbc.png
# ⚠️  missing page D:\python\data\images\image_d8dc5ffe-eda3-4f11-a91b-8854fe644ccb.png
# ⚠️  missing page D:\python\data\images\image_ad03fdc2-8c05-4c3a-a019-af68ac3635fc.png
# ⚠️  missing page D:\python\data\images\image_dba07de1-4f65-48ec-821c-c5bc9fd11ce6.png
# ⚠️  missing page D:\python\data\images\image_91344002-e630-4a78-9d9b-2e18cfe5c48e.png
# ⚠️  missing page D:\python\data\images\image_d43caa7a-50c0-402c-a771-3cbd0abe2e43.png
# ⚠️  missing page D:\python\data\images\image_314cac0c-faf2-4c03-bbdc-27cab57b8f39.png
# ⚠️  missing page D:\python\data\images\image_bec6cc98-1ab4-4b10-85c1-3690d01daa69.png
# ⚠️  missing page D:\python\data\images\image_58556eb5-ade5-4913-8818-ffdc8b499943.png
# ⚠️  missing page D:\python\data\images\image_cce3c9f3-83e0-4803-b1bc-0ba011ea8481.png
# ⚠️  missing page D:\python\data\images\image_2d039cac-6359-4b16-a177-36d4b44761a9.png
# ⚠️  missing page D:\python\data\images\image_2861a6a5-0461-4e0f-8ff9-4795434c9bac.png
# ⚠️  missing page D:\python\data\images\image_ff7ffb22-164e-4700-8ca7-aa653b390689.png
# ⚠️  missing page D:\python\data\images\image_e994d523-f514-4b21-8270-1b36e109a0f7.png
# ⚠️  missing page D:\python\data\images\image_46bcb043-6cb0-40e9-8cb8-f246e7638ebc.png
# ⚠️  missing page D:\python\data\images\image_c916f52a-966a-4d64-bbee-a10fd923f609.png
# ⚠️  missing page D:\python\data\images\image_412c31fb-9dcd-40b5-a464-7276a2c21de8.png
# ⚠️  missing page D:\python\data\images\image_8b291f67-3794-4fb7-b07b-bf88907094f6.png
# ⚠️  missing page D:\python\data\images\image_e5e14ed3-571e-47df-8df1-74b51add2f3a.png
# ⚠️  missing page D:\python\data\images\image_ec1eae8e-3c29-4100-afff-1d58b1e72e16.png
# ⚠️  missing page D:\python\data\images\image_09a2471c-498c-4d2f-88ce-a89ec6c1984b.png
# ⚠️  missing page D:\python\data\images\image_27e4e939-770f-421e-8705-db01d4f8cd20.png
# ⚠️  missing page D:\python\data\images\image_c3db120f-9269-43ce-979f-2c8c6ae144e8.png
# ⚠️  missing page D:\python\data\images\image_aa93dc66-869d-4ba1-b05f-5fd788ea8fe2.png
# ⚠️  missing page D:\python\data\images\image_2a7b9e3d-1286-4bd4-9173-899ddfcfe55f.png
# ⚠️  missing page D:\python\data\images\image_6cc4f242-c9b9-4d03-beda-95c0c5ed4f63.png
# ⚠️  missing page D:\python\data\images\image_e0980439-1396-49b1-8cbb-00b3765a428a.png
# ⚠️  missing page D:\python\data\images\image_1681fb04-0c7d-4f69-a524-ed9d11e6409f.png
# ⚠️  missing page D:\python\data\images\image_0ba61e4f-2f17-4967-a45f-8375c72353bf.png
# ⚠️  missing page D:\python\data\images\image_40238190-1947-4fe4-bf3f-e79bbc2a42fe.png
# ⚠️  missing page D:\python\data\images\image_2a7dd224-a1c2-46df-96df-3cb754a5ad8e.png
# ⚠️  missing page D:\python\data\images\image_81dc779e-c1fb-4e3e-84db-d5270f6e143f.png
# ⚠️  missing page D:\python\data\images\image_005b0fb7-9c7e-49b2-b12f-0ce1ce4021b5.png
# ⚠️  missing page D:\python\data\images\image_f5508d9a-f837-4c62-9824-93c272fd842e.png
# ⚠️  missing page D:\python\data\images\image_50218d5b-a322-45ca-919f-00c384c8f323.png
# ⚠️  missing page D:\python\data\images\image_22a592d6-60d3-4ec3-8765-f728a52559d4.png
# ...
# ⚠️  missing page D:\python\data\images\image_5304ba3f-7a9b-4a4a-a1eb-2a3e50341185.png
# ⚠️  missing page D:\python\data\images\image_e9ef06c0-bea4-4164-ba3e-f49d19c19b65.png
# ⚠️  missing page D:\python\data\images\image_d7c928f6-59da-4456-ae92-cd718c96d2df.png
# ⚠️  missing page D:\python\data\images\image_e73b22aa-a65c-460d-a241-856c723c4f0a.png
# ⚠️  missing page D:\python\data\images\image_466392f1-46df-4ce5-9a67-86819e66e9f0.png
# ⚠️  missing page D:\python\data\images\image_dfbd9f9c-40ba-47f5-9e63-c40786dc0a3a.png
# ⚠️  missing page D:\python\data\images\image_b3c83f9a-91d8-45c0-915a-4e9b64947598.png
# ⚠️  missing page D:\python\data\images\image_9ec6ae01-eb90-40ee-9349-db1fca230898.png
# ⚠️  missing page D:\python\data\images\image_35b19c18-a22e-47db-9ca7-cac970a3eed7.png
# ⚠️  missing page D:\python\data\images\image_6251cd5a-8f74-4b3f-bd47-58599c2e1a8c.png
# ⚠️  missing page D:\python\data\images\image_7c8a765a-dd61-4bb2-85d4-96ccdd89208d.png
# ⚠️  missing page D:\python\data\images\image_b232176d-073e-4211-8e81-7e741d82c613.png
# ⚠️  missing page D:\python\data\images\image_2d50baad-1dba-4b83-9c24-d7932e06e12f.png
# ⚠️  missing page D:\python\data\images\image_2a2b4a39-c26f-490e-9c58-ac6789ceded1.png
# ⚠️  missing page D:\python\data\images\image_bf5cf40f-47aa-423a-bbcf-2c59f34e1d97.png
# ⚠️  missing page D:\python\data\images\image_0d0a24ee-8f5f-49e4-bdee-b5f0899bdc85.png
# ⚠️  missing page D:\python\data\images\image_1f4eeca8-b80c-4c23-a294-e19142099a25.png
# ⚠️  missing page D:\python\data\images\image_6e1b4b24-9c86-4ace-b21d-cdfd2f792c37.png
# ⚠️  missing page D:\python\data\images\image_02fe88dc-7a78-4b9d-9dcc-9bd8ac43be13.png
# ⚠️  missing page D:\python\data\images\image_96183679-edcd-4a62-baed-a046f1e3367b.png
# ⚠️  missing page D:\python\data\images\image_fb966942-2ba2-4f6b-b59e-c13d8043e337.png
# ⚠️  missing page D:\python\data\images\image_7d85c0d0-64de-45af-9def-877e1511401b.png
# ⚠️  missing page D:\python\data\images\image_22614975-0ecc-4ecc-ac22-64cd3255e7e1.png
# ⚠️  missing page D:\python\data\images\image_080d5115-205e-423b-b453-f014efa1c5c8.png
# ⚠️  missing page D:\python\data\images\image_3f4a60c9-9498-4de9-95b1-72c75cc921a2.png
# ⚠️  missing page D:\python\data\images\image_00ca7146-d38b-4b0a-b8fa-c97c99691338.png
# ⚠️  missing page D:\python\data\images\image_1126829f-a172-4978-bed3-a87086d38854.png
# ⚠️  missing page D:\python\data\images\image_d9e69212-55a1-494e-8afd-4fdf7c33a60c.png
# ⚠️  missing page D:\python\data\images\image_4682c19a-ff96-4fbf-bff9-0e9aefc36dd5.png
# ⚠️  missing page D:\python\data\images\image_52c02b0f-825f-431d-bb91-69131a9c0cc1.png
# ⚠️  missing page D:\python\data\images\image_cdd99560-2097-4c34-a3e3-09a278e816de.png
# ⚠️  missing page D:\python\data\images\image_4ce0f44e-44a9-440b-94eb-43aa6a7513c1.png
# ⚠️  missing page D:\python\data\images\image_d08e4470-f9cc-4f84-b557-dc20dfc10998.png
# ⚠️  missing page D:\python\data\images\image_1ba661a4-0086-4974-9f3e-12d637c1b797.png
# ⚠️  missing page D:\python\data\images\image_6253919a-d5b6-4710-8f54-9b015775d99e.png
# ⚠️  missing page D:\python\data\images\image_cc159559-6140-4bdd-85e3-fff19124bd4b.png
# ⚠️  missing page D:\python\data\images\image_df2b0771-ebfe-4202-a288-92fbb1cd2da9.png
# ⚠️  missing page D:\python\data\images\image_af56fc8b-ba67-4ed8-b1ac-87e2b9e25856.png
# ⚠️  missing page D:\python\data\images\image_119bd671-5755-4685-827c-f038e79f3f3c.png
# ⚠️  missing page D:\python\data\images\image_5e2a3853-af97-4434-8c68-3f8a725d8b80.png
# ⚠️  missing page D:\python\data\images\image_1d181daa-6ac3-41eb-92a1-916ac99ab829.png
# ⚠️  missing page D:\python\data\images\image_66343ca1-8f15-40cd-8d72-6566f9cd32ff.png
# ⚠️  missing page D:\python\data\images\image_59a23929-404e-406a-bd7c-d35c73e15a0b.png
# ⚠️  missing page D:\python\data\images\image_5680909d-5b08-4a8a-8f31-3e5bf7808772.png
# ⚠️  missing page D:\python\data\images\image_224d8422-67cb-4f30-9ea5-c37871037db6.png
# ⚠️  missing page D:\python\data\images\image_3c0f56f0-e4db-4dc3-b715-2d0b5d0e8f51.png
# ⚠️  missing page D:\python\data\images\image_cdd4c8bc-3acd-4c6a-ab7d-73c62621a0be.png
# ⚠️  missing page D:\python\data\images\image_94b0b523-c7fc-44d3-9ba8-52469af888d5.png
# ⚠️  missing page D:\python\data\images\image_8abd069b-427e-4916-8361-55ca260d193b.png
# ⚠️  missing page D:\python\data\images\image_9d196ac4-60be-4c52-9b71-4fd466a5db16.png
# ⚠️  missing page D:\python\data\images\image_6fb5d671-1533-4be3-a60d-c71c942fce79.png
# ⚠️  missing page D:\python\data\images\image_36dc0112-7ba5-4274-a9ef-ff7a6175964f.png
# ⚠️  missing page D:\python\data\images\image_9820a298-a6a3-4b42-80e8-ea284b61c01a.png
# ⚠️  missing page D:\python\data\images\image_2d6a1739-1a8d-4954-adaf-0f48fbb97bac.png
# ⚠️  missing page D:\python\data\images\image_b3ec22c7-2ad3-47d1-963b-654ac9af41d6.png
# ⚠️  missing page D:\python\data\images\image_b1a5f98d-c7d3-45c8-a1c6-206128951f7c.png
# ⚠️  missing page D:\python\data\images\image_3be583e5-d950-4072-8e9a-148c27199bd9.png
# ⚠️  missing page D:\python\data\images\image_397cac42-6162-4920-97d0-483cf38f68ba.png
# ⚠️  missing page D:\python\data\images\image_b00632ab-2b0c-4b36-a72e-8118a918f8a9.png
# ⚠️  missing page D:\python\data\images\image_6edc0c3c-2ddb-44d5-b612-b4534f48a35a.png
# ⚠️  missing page D:\python\data\images\image_cba554aa-9c76-489a-af7a-c2af971b93a8.png
# ⚠️  missing page D:\python\data\images\image_0733ad8f-0c8d-494d-96da-5fccec71c175.png
# ⚠️  missing page D:\python\data\images\image_3a743af2-c776-4b8b-9b14-611fa1173b94.png
# ⚠️  missing page D:\python\data\images\image_2d1e45ab-53f5-49f7-bc7f-4c00219e41e3.png
# ⚠️  missing page D:\python\data\images\image_143f5dca-31fd-470c-bc12-2a2fe11497e5.png
# ⚠️  missing page D:\python\data\images\image_3d701ab3-30df-4ac4-b04f-dfe5fdd7afad.png
# ⚠️  missing page D:\python\data\images\image_7d7d1d77-9986-4c85-a096-fe9bd1a3e01f.png
# ⚠️  missing page D:\python\data\images\image_e5f3040c-9ca7-449b-8f20-44da3b1731cd.png
# ⚠️  missing page D:\python\data\images\image_fc05942f-d668-4d8e-a9ee-c7639c5d0f59.png
# ⚠️  missing page D:\python\data\images\image_008ebd34-1aef-4dae-8dc5-b8138d530929.png
# ⚠️  missing page D:\python\data\images\image_80dcc371-532f-4fd2-bc7b-0d129c0393ad.png
# ⚠️  missing page D:\python\data\images\image_5c11da41-a27c-460f-afcb-6cfc763ae7db.png
# ⚠️  missing page D:\python\data\images\image_2304b9b7-aa38-4c3c-aba8-14fa4098b9ac.png
# ⚠️  missing page D:\python\data\images\image_7cded55e-c78c-46c8-9f4c-c646e5804073.png
# ⚠️  missing page D:\python\data\images\image_29ce13a8-071d-4ac5-b4ed-5d09a62511ee.png
# ⚠️  missing page D:\python\data\images\image_b727a74f-5411-4505-8ce9-8844c36f19c3.png
# ⚠️  missing page D:\python\data\images\image_93c17829-96f8-44f5-8f21-a99696270b60.png
# ⚠️  missing page D:\python\data\images\image_1101182f-82fe-4a92-860b-7f0d0b8f5c59.png
# ⚠️  missing page D:\python\data\images\image_08a19d93-e500-4498-b20c-84cb767d7e46.png
# ⚠️  missing page D:\python\data\images\image_5dfb31a9-555e-4e47-bab4-09b7250a54b8.png
# ⚠️  missing page D:\python\data\images\image_f2383ae2-af8d-4008-bb16-781edd4a0000.png
# ⚠️  missing page D:\python\data\images\image_689c6592-18d4-405e-9f31-41b09a294283.png
# ⚠️  missing page D:\python\data\images\image_4215f168-fe53-4315-935f-cb7a4d498102.png
# ⚠️  missing page D:\python\data\images\image_2dd0a944-ccc6-4677-8813-373b024dd4e9.png
# ⚠️  missing page D:\python\data\images\image_a05280ed-1aca-4f6e-a02c-54379ea0ea7d.png
# ⚠️  missing page D:\python\data\images\image_58e69d27-41b7-4c0b-a5b7-bac35465d52d.png
# ⚠️  missing page D:\python\data\images\image_97d3c28c-3fa6-4938-bc61-973849a1586f.png
# ⚠️  missing page D:\python\data\images\image_ea7e2388-1c48-4fc5-b209-e61383bac7da.png
# ⚠️  missing page D:\python\data\images\image_2fbdc457-893c-4895-ab52-5975918a9732.png
# ⚠️  missing page D:\python\data\images\image_5ba3cfba-444a-4c5a-917e-46fd82d3e449.png
# ⚠️  missing page D:\python\data\images\image_5df39a0c-f739-4a13-8164-12f897f78448.png
# ⚠️  missing page D:\python\data\images\image_650e07bc-4b23-4858-93af-975c6d1e01a7.png
# ⚠️  missing page D:\python\data\images\image_81f8f435-2529-4c61-83e4-9b7df2c6517e.png
# ⚠️  missing page D:\python\data\images\image_8f7da18c-a084-4ce0-9968-d03646ff4f7f.png
# ⚠️  missing page D:\python\data\images\image_9ae2dc38-08b3-4e70-8fa6-65611c5ec1cf.png
# ⚠️  missing page D:\python\data\images\image_f9bb209e-ec32-449b-a223-87796ba97b93.png
# ⚠️  missing page D:\python\data\images\image_64450dfb-c362-4b33-b787-4b834a5b38e1.png
# ⚠️  missing page D:\python\data\images\image_900fc35f-1bbd-4d49-b67a-9d6c1352bcd0.png
# ⚠️  missing page D:\python\data\images\image_2509f4b0-6f53-4a70-bff6-f510d3872bc4.png
# ⚠️  missing page D:\python\data\images\image_877305ae-baed-4c2d-a7d5-9d4886c8a076.png
# ⚠️  missing page D:\python\data\images\image_a1e452cd-7da0-4eda-9314-54a3f6ee302d.png
# ⚠️  missing page D:\python\data\images\image_a197ef26-982f-4af8-af56-71b374bb2d66.png
# ⚠️  missing page D:\python\data\images\image_cf71b2ce-f660-4a52-a15f-a2ec482770ad.png
# ⚠️  missing page D:\python\data\images\image_c266f4fe-fe39-4edb-a658-73fd28645199.png
# ⚠️  missing page D:\python\data\images\image_8677aef5-5106-4efd-8946-5e3eae893e2c.png
# ⚠️  missing page D:\python\data\images\image_267f5bdf-5443-45f1-8d9c-10709e7d35a2.png
# ⚠️  missing page D:\python\data\images\image_dee379aa-d509-4e23-9448-146a6e6f652f.png
# ⚠️  missing page D:\python\data\images\image_3065b96b-ccb3-4025-bdce-77427a2b2095.png
# ⚠️  missing page D:\python\data\images\image_fc15748c-6304-4f02-8cf3-607b2367f212.png
# ⚠️  missing page D:\python\data\images\image_1ccdb613-7b95-4654-bc8d-4c3ac02983cf.png
# ⚠️  missing page D:\python\data\images\image_1e5ce20e-02c0-4e3d-8033-1e0724f359f9.png
# ⚠️  missing page D:\python\data\images\image_891d2cf6-8c2e-4b04-93af-ae14a9548b4f.png
# ⚠️  missing page D:\python\data\images\image_8b141afc-a943-4590-856a-98cb42840cc4.png
# ⚠️  missing page D:\python\data\images\image_8b811433-1135-4977-a036-b4a20f799342.png
# ⚠️  missing page D:\python\data\images\image_ded1c64a-8bcb-4c33-acc0-df65004bed3a.png
# ⚠️  missing page D:\python\data\images\image_970d9e38-8f44-4d2e-9c6c-62e12824cc54.png
# ⚠️  missing page D:\python\data\images\image_12700635-3671-487a-87c3-18ae692fc973.png
# ⚠️  missing page D:\python\data\images\image_219538ca-620c-49e4-954f-9e3c865f8e10.png
# ⚠️  missing page D:\python\data\images\image_bfc7d2d9-36da-4c16-8db1-532219f9f6f6.png
# ⚠️  missing page D:\python\data\images\image_4cfef284-b6cc-4062-91e1-0d158471272c.png
# ⚠️  missing page D:\python\data\images\image_e05dffe1-3b5c-4c42-a4fc-64d6593e444a.png
# ⚠️  missing page D:\python\data\images\image_468ebe2e-c5c0-44d3-8377-cea5a3c0d84d.png
# ⚠️  missing page D:\python\data\images\image_48a723cd-5f31-4d32-84e1-d4d729c87af0.png
# ⚠️  missing page D:\python\data\images\image_51e83908-6f8f-4b11-a239-2b5d766f7327.png
# ⚠️  missing page D:\python\data\images\image_4d50015d-8e40-4433-b65a-24bc728c22a6.png
# ⚠️  missing page D:\python\data\images\image_ccc1878e-4ae5-4e45-8a22-36517273d6f2.png
# ⚠️  missing page D:\python\data\images\image_3e4480f7-e0b6-46d1-8cd6-38b7dbb2a483.png
# ⚠️  missing page D:\python\data\images\image_cd9b6aac-0476-4ac7-96d5-a9d5756dea31.png
# ⚠️  missing page D:\python\data\images\image_38f1e5bd-0b98-428d-a1a6-505647e411e1.png
# ⚠️  missing page D:\python\data\images\image_fd9d1ec4-d3d2-4ea4-ab58-bb08521d9235.png
# ⚠️  missing page D:\python\data\images\image_bdde001c-6298-4718-98ce-12d9ca93c439.png
# ⚠️  missing page D:\python\data\images\image_d99a09cb-7a39-4f32-8a00-c5761a3b0fd3.png
# ⚠️  missing page D:\python\data\images\image_6e635b48-0a91-4220-9555-f73b7bc0d323.png
# ⚠️  missing page D:\python\data\images\image_8ffdc62b-53ae-4981-986b-135729a07f20.png
# ⚠️  missing page D:\python\data\images\image_b89cd922-e305-4337-859a-c650c4dc3140.png
# ⚠️  missing page D:\python\data\images\image_d8098b0d-1c17-4960-8e4b-b50c78452d7a.png
# ⚠️  missing page D:\python\data\images\image_0fe4694d-dc33-45e5-99bf-5d911152c745.png
# ⚠️  missing page D:\python\data\images\image_9b4aac04-ee82-4285-a1d1-e38091e143d4.png
# ⚠️  missing page D:\python\data\images\image_f8428b6e-c231-4f6f-bc41-2838290e5267.png
# ⚠️  missing page D:\python\data\images\image_a423363f-01dd-437c-8d9c-8f3466586fff.png
# ⚠️  missing page D:\python\data\images\image_08e11ae7-dec7-4ae3-b888-c5a5b59a6fdd.png
# ⚠️  missing page D:\python\data\images\image_fc50ecb1-31a2-475f-81f2-441c062eb5cc.png
# ⚠️  missing page D:\python\data\images\image_6d6da2e3-f75b-4d11-99da-c32dc33bf5af.png
# ⚠️  missing page D:\python\data\images\image_ed1faa46-5f04-4315-bc15-a87229d0c011.png
# ⚠️  missing page D:\python\data\images\image_c91f7e4a-b9ff-4612-aa10-22c86fb2f6c3.png
# ⚠️  missing page D:\python\data\images\image_706bcdce-e3bc-45d2-a1c1-243383cad963.png
# ⚠️  missing page D:\python\data\images\image_0f5578aa-c5fa-4615-97aa-7b0c32c16213.png
# ⚠️  missing page D:\python\data\images\image_e3e973c4-3158-4da0-8f9d-677399569d97.png
# ⚠️  missing page D:\python\data\images\image_cdce6a0f-f36a-4cdb-8f79-bfa574c1929d.png
# ⚠️  missing page D:\python\data\images\image_a23be4d1-9886-45e4-89f3-51ebc4cd85a2.png
# ⚠️  missing page D:\python\data\images\image_aa30e233-dfa1-4a2d-b7a7-0e10c85059e9.png
# ⚠️  missing page D:\python\data\images\image_f0e4b748-edd0-41e6-b9b5-e040e0f4397b.png
# ⚠️  missing page D:\python\data\images\image_16cbf960-ec9f-4d8e-a1ec-92b77d94b159.png
# ⚠️  missing page D:\python\data\images\image_3e595d7d-2587-4453-8147-ae553e403338.png
# ⚠️  missing page D:\python\data\images\image_c62a8868-9f8d-4802-82c9-25664b742d7f.png
# ⚠️  missing page D:\python\data\images\image_f1c29784-7042-4a64-8206-7336906e2d2c.png
# ⚠️  missing page D:\python\data\images\image_107e99ce-8f76-4af1-abe5-43719823efd6.png
# ⚠️  missing page D:\python\data\images\image_61278acd-4707-475c-ba59-e01f68bef61e.png
# ⚠️  missing page D:\python\data\images\image_8b45bfd8-195d-4461-b616-15f97d0e5ab9.png
# ⚠️  missing page D:\python\data\images\image_bbe47d38-2254-43b8-8b51-9ca279832735.png
# ⚠️  missing page D:\python\data\images\image_aba3c96f-950d-4dfc-8369-37eea4990814.png
# ⚠️  missing page D:\python\data\images\image_6c31c090-67e6-4894-a54e-a34c56ec47d0.png
# ⚠️  missing page D:\python\data\images\image_14b03c6d-21cc-49ee-849a-5acda614b821.png
# ⚠️  missing page D:\python\data\images\image_350cb0a9-f207-4e30-b88c-5bad83c3764d.png
# ⚠️  missing page D:\python\data\images\image_54ca57da-dbcf-48dd-8f89-f1f7b5e793fb.png
# ⚠️  missing page D:\python\data\images\image_04784b70-a70b-4308-91a9-c6d7d4fc5dbe.png
# ⚠️  missing page D:\python\data\images\image_5c84e883-0a5c-4868-a9b1-efc554ee98b3.png
# ⚠️  missing page D:\python\data\images\image_e0b69bde-0e82-47e3-b164-d786aeabdfaa.png
# ⚠️  missing page D:\python\data\images\image_88c8b1dd-6f10-4c34-b0c3-97d47659e344.png
# ⚠️  missing page D:\python\data\images\image_0c35c202-fd5d-4575-909d-6359657aafbc.png
# ⚠️  missing page D:\python\data\images\image_b7cdf36b-086a-4337-b595-d78a6bf00294.png
# ⚠️  missing page D:\python\data\images\image_4709432a-061b-4b3b-9afb-978454c6bf14.png
# ⚠️  missing page D:\python\data\images\image_1e91529a-611c-4f9a-975c-5b5dfb9725fc.png
# ⚠️  missing page D:\python\data\images\image_341f609e-fe8d-4d60-9209-bac1a26bf948.png
# ⚠️  missing page D:\python\data\images\image_2d594f61-d7e2-4fe6-bfd8-56602f2e527e.png
# ⚠️  missing page D:\python\data\images\image_c70311e2-ca2b-414e-8e9d-80938356e083.png
# ⚠️  missing page D:\python\data\images\image_7251153b-cd36-4717-bee1-242e34ad7e71.png
# ⚠️  missing page D:\python\data\images\image_0ddff055-b8e8-4fc2-b08c-85af6edc6430.png
# ⚠️  missing page D:\python\data\images\image_dc4a79e6-6710-44c1-9804-6fef228ca087.png
# ⚠️  missing page D:\python\data\images\image_269209fc-7421-4bc0-8722-6099a7e12a4d.png
# ⚠️  missing page D:\python\data\images\image_dc99b70b-e557-49b3-995e-15491922374b.png
# ⚠️  missing page D:\python\data\images\image_adff1288-543d-4983-90d2-8a88aba4b8d0.png
# ⚠️  missing page D:\python\data\images\image_668cc1c7-24ff-442d-ae64-68f6feb20338.png
# Unique grapheme clusters: 146
# ✅ Saved 28 line crops.
# Avg lines per page: 9.333333333333334
# chars.txt  → D:\python\data\line_crops\chars.txt
# labels.json→ D:\python\data\line_crops\labels.json

# %%
# ----------------------------------------------------------------------
# Load charset from a plain-text file saved as one character per line
# ----------------------------------------------------------------------
from pathlib import Path

charset_path = Path(r"d:/python/data/line_crops/chars.txt")   # <- point to your file
with charset_path.open("r", encoding="utf-8") as f:
    # keep original order, strip new-lines and ignore blank lines
    charset = [line.rstrip("\n") for line in f if line.strip()]

# Optionally verify there are no duplicates
dupes = [c for c, n in __import__("collections").Counter(charset).items() if n > 1]
if dupes:
    raise ValueError(f"Duplicate entries in charset.txt: {dupes}")

# Build look-up tables
char2idx  = {c: i for i, c in enumerate(charset)}
idx2char  = {i: c for c, i in char2idx.items()}
blank_id  = len(charset)          # CTC blank token index

print(f"Loaded {len(charset)} symbols. First 10 → {charset[:10]}")
# Out:
# Loaded 145 symbols. First 10 → ['"', ',', '.', '0', '1', '2', '3', '4', '5', '7']

# %%
# ─────────────────────────────────────────────────────────────────────
# Sinhala OCR – ResNet-Transformer + CTC
# ---------------------------------------------------------------------
# ❶  Image crops: 32 × 512  (RGB or gray, any aspect OK)
# ❷  labels.json  –  { "img_000123.png": "ඉතාලි …", ... }
# ❸  chars.txt    –  one grapheme-cluster per line (order = class id-1)
# ---------------------------------------------------------------------
#    python train_sinhala_ocr.py
# ─────────────────────────────────────────────────────────────────────
import json, random, regex, os
from pathlib import Path
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import CTCLoss, TransformerEncoder, TransformerEncoderLayer
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T
import torchvision.models as models
# ---------------------------------------------------------------------
# FILE LOCATIONS – edit to match your drive
LABELS_JSON = Path(r"d:/python/data/line_crops/labels.json")
CHARS_TXT   = Path(r"d:/python/data/line_crops/chars.txt")
IMG_DIR     = Path(r"d:/python/data/line_crops")
CKPT_DIR    = Path(r"d:/python/checkpoints"); CKPT_DIR.mkdir(exist_ok=True)
# ---------------------------------------------------------------------
# CHARSET & LABEL MAP
with LABELS_JSON.open(encoding="utf-8") as f:
    line_map: dict[str, str] = json.load(f)

with CHARS_TXT.open(encoding="utf-8") as f:
    charset = [ln.rstrip("\n") for ln in f if ln.strip()]

char2idx = {c: i + 1 for i, c in enumerate(charset)}   # 0 = blank
idx2char = {i: c for c, i in char2idx.items()}
blank_idx = 0

cluster_re = regex.compile(r"\X", regex.UNICODE)
def split_clusters(s):       # drop whitespace clusters
    return [c for c in cluster_re.findall(s) if not c.isspace()]

img_paths, labels = [], []
for fname, text in line_map.items():
    img_file = IMG_DIR / fname
    if not img_file.exists():
        continue
    clust = split_clusters(text)
    if any(c not in char2idx for c in clust):
        print("⚠️  unseen cluster in", fname); continue
    img_paths.append(str(img_file))
    labels.append(clust)

print(f"Loaded {len(img_paths)} lines   charset = {len(charset)} symbols")
# ---------------------------------------------------------------------
# DATASET
class SinhalaOCRDataset(Dataset):
    def __init__(self, paths, lbls, c2i, size=(32,512), augment=False):
        self.paths, self.lbls, self.c2i, self.augment = paths, lbls, c2i, augment
        self.base_tf = T.Compose([
            T.Grayscale(num_output_channels=3),
            T.Resize(size, antialias=True),
            T.ToTensor(),
            T.Normalize(mean=[0.485,0.456,0.406],
                        std =[0.229,0.224,0.225]),
        ])
        self.aug_tf = T.Compose([
            T.RandomRotation(2),
            T.ColorJitter(0.1,0.1)
        ])

    def __len__(self): return len(self.paths)
    def __getitem__(self, idx):
        img = Image.open(self.paths[idx]).convert("RGB")
        if self.augment and random.random() < 0.5:
            img = self.aug_tf(img)
        img = self.base_tf(img)
        tgt = torch.tensor([self.c2i[c] for c in self.lbls[idx]],
                           dtype=torch.long)
        return img, tgt

def collate(batch):
    imgs, lbls = zip(*batch)
    return torch.stack(imgs, 0), list(lbls)   # imgs -> (B,3,32,512)

train_ds = SinhalaOCRDataset(img_paths, labels, char2idx,
                             size=(32,512), augment=True)
train_loader = DataLoader(train_ds, batch_size=4, shuffle=True,
                          num_workers=0, collate_fn=collate)
# ---------------------------------------------------------------------
# MODEL
class OCRModel(nn.Module):
    def __init__(self, n_chars):
        super().__init__()
        base = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
        base.conv1.stride = (1,1)
        base.maxpool = nn.Identity()
        self.cnn = nn.Sequential(*list(base.children())[:-2])      # (B,512,H',W')
        self.tcn = nn.Conv1d(512,256,kernel_size=3,padding=1,groups=4)
        enc = TransformerEncoderLayer(d_model=256, nhead=4, dim_feedforward=512)
        self.tr  = TransformerEncoder(enc, num_layers=2)
        self.head = nn.Linear(256, n_chars+1)   # + blank
        nn.init.constant_(self.head.bias, -2.0) # discourage blanks
        self.head.bias.data[blank_idx] = 0.0    # but not too much

    def forward(self, x):                       # x (B,3,32,512)
        f = self.cnn(x)                         # (B,512,H',W')
        f = F.adaptive_avg_pool2d(f, (1,64)).squeeze(2)   # (B,512,64)
        f = self.tcn(f)                         # (B,256,64)
        seq = f.permute(2,0,1)                  # (64,B,256)
        h   = self.tr(seq)                      # (64,B,256)
        return F.log_softmax(self.head(h), dim=2)  # (T,B,C)
# ---------------------------------------------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model  = OCRModel(len(charset)).to(device)
opt    = torch.optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-4)
sched  = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=50)
ctc    = CTCLoss(blank=blank_idx, zero_infinity=True)
# ---------------------------------------------------------------------
epochs, accum = 50, 4
for epoch in range(1, epochs+1):
    model.train(); opt.zero_grad(); total, steps = 0.0, 0
    for imgs, lbls in train_loader:
        imgs = imgs.to(device)
        logp = model(imgs)                     # (T,B,C)

        T_lens = torch.full((logp.size(1),), logp.size(0),
                            dtype=torch.long, device=device)
        L_lens = torch.tensor([t.size(0) for t in lbls],
                             dtype=torch.long, device=device)
        targets = torch.cat([t.to(device) for t in lbls])

        loss = ctc(logp, targets, T_lens, L_lens) / accum
        loss.backward(); total += loss.item(); steps += 1
        if steps % accum == 0:
            opt.step(); opt.zero_grad()

    if steps % accum:           # flush leftover grads
        opt.step(); opt.zero_grad()
    sched.step()

    print(f"Epoch {epoch:02d}  loss {total/steps:.4f}  lr {sched.get_last_lr()[0]:.2e}")

    # quick sanity-check decode on one random training line
    model.eval()
    with torch.no_grad():
        img, gt = train_ds[random.randint(0, len(train_ds)-1)]
        pred = model(img.unsqueeze(0).to(device)).squeeze(1)   # (T,C)
        arg  = torch.argmax(pred, 1).cpu().tolist()
        txt, prev = [], blank_idx
        for a in arg:
            if a != prev and a != blank_idx:
                txt.append(idx2char[a])
            prev = a
        print(" GT:", "".join(idx2char[i.item()] for i in gt))
        print(" PR:", "".join(txt))
        print("-"*50)

    # save checkpoint each epoch
    torch.save({
        "epoch": epoch,
        "model_state": model.state_dict(),
        "optimizer_state": opt.state_dict(),
        "charset": charset,
    }, CKPT_DIR / f"sinhala_ocr_epoch{epoch:02d}.pt")
# Out:
# Loaded 28 lines   charset = 145 symbols
# Epoch 01  loss 2.3501  lr 3.00e-04
#  GT: බලපෑම්කරතිබේ.
#  PR:
# --------------------------------------------------
# Epoch 02  loss 1.2888  lr 2.99e-04
#  GT: අනුවදෙවියන්වහන්සේවිශ්වයමවාඇත්තේමිනිසාගේ
#  PR:
# --------------------------------------------------
# Epoch 03  loss 1.3053  lr 2.97e-04
#  GT: යෝජනාවක්‌ඉදිරිපත්කරනලදි.ඉන්ඔහුවඉතාලි
#  PR:
# --------------------------------------------------
# Epoch 04  loss 1.2135  lr 2.95e-04
#  GT: අනුවදෙවියන්වහන්සේවිශ්වයමවාඇත්තේමිනිසාගේ
#  PR:
# --------------------------------------------------
# Epoch 05  loss 1.1467  lr 2.93e-04
#  GT: ගැනදන්නාඅයකුඒමගහැරයෑමටහෝතමාටවිෂය
#  PR: න්ර
# --------------------------------------------------
# Epoch 06  loss 1.1443  lr 2.89e-04
#  GT: බටහිරමතවාදයකි.අමරතුංගමහතාගේඅවුල්අදහස්
#  PR: රරරන්
# --------------------------------------------------
# Epoch 07  loss 1.0877  lr 2.86e-04
#  GT: ග්රෑන්ඩ්කවුන්සිලයේනිගමනයන්ටඅනුව1943දීජුලි
#  PR: න්
# --------------------------------------------------
# Epoch 08  loss 1.0420  lr 2.81e-04
#  GT: ගැනදන්නාඅයකුඒමගහැරයෑමටහෝතමාටවිෂය
#  PR:
# --------------------------------------------------
# Epoch 09  loss 1.0175  lr 2.77e-04
#  GT: සිටීමටඉඩක්නොදීමිත්රපාක්‌ෂිකයන්ටභාරදීමේ
#  PR: න්ර
# --------------------------------------------------
# Epoch 10  loss 0.9561  lr 2.71e-04
#  GT: ලැබෙයි.එහිඅමරතුංගමහතාකියාඇත්තේබටහිර
#  PR: රමය
# --------------------------------------------------
# Epoch 11  loss 0.8838  lr 2.66e-04
#  GT: ග්රෑන්ඩ්කවුන්සිලයේනිගමනයන්ටඅනුව1943දීජුලි
#  PR: න්න්ලමයන්අවලි
# --------------------------------------------------
# Epoch 12  loss 0.8422  lr 2.59e-04
#  GT: තිබේ.පොලවටකිලෝමීටර්40කටවඩාඑපිටින්ඇති
#  PR: ලටලටටවටපින්
# --------------------------------------------------
# Epoch 13  loss 0.7548  lr 2.53e-04
#  GT: මෙමස්තරයඅයනගෝලයලෙසහැදින්වේ.
#  PR: මරඅයලලන්
# --------------------------------------------------
# Epoch 14  loss 0.7058  lr 2.46e-04
#  GT: අගමැතිතනතුරින්පහකළයුතුබවටතීන්දුවූයේය.
#  PR: නන්කයුවටන්
# --------------------------------------------------
# Epoch 15  loss 0.6379  lr 2.38e-04
#  GT: "ඇල්ප්ස්‌හි"ගර්ඩාවිලටසමීපහමුදාකඳවුරකරැඳවීමට
#  PR: ලරවිලටකරමට
# --------------------------------------------------
# Epoch 16  loss 0.5874  lr 2.30e-04
#  GT: අගමැතිතනතුරින්පහකළයුතුබවටතීන්දුවූයේය.
#  PR: නරින්හකයුතුබවටන්ය
# --------------------------------------------------
# Epoch 17  loss 0.5267  lr 2.22e-04
#  GT: 25දිනඔහුවපදවියෙන්පහකරරාජ්යබලයහමුදාව
#  PR: දිනහුවපවින්හකරයලයහයව
# --------------------------------------------------
# Epoch 18  loss 0.4867  lr 2.14e-04
#  GT: අපපෘතුවිවායුගෝලයේඉහලස්තරකීපයක්
#  PR: අපතුවිවායුලයේඉහලස්තරපය
# --------------------------------------------------
# Epoch 19  loss 0.4364  lr 2.05e-04
#  GT: ඉතාලිරජයේවිධායකයන්28දෙනකුගෙන්යුතුවූ
#  PR: ඉතාලිරයේවියයන්නන්යුතු
# --------------------------------------------------
# Epoch 20  loss 0.3972  lr 1.96e-04
#  GT: බටහිරමතවාදයකි.අමරතුංගමහතාගේඅවුල්අදහස්
#  PR: බටහිරමතවාදය.අමරතුංගමහතාඅවුඅදහ
# --------------------------------------------------
# Epoch 21  loss 0.3592  lr 1.87e-04
#  GT: ප්රයෝජනයපිණිසයයන්නබටහිරදර්ශනයය.
#  PR: ප්රයෝජනයපිණිසයයයන්නබටහිරදර්ශනයය
# --------------------------------------------------
# Epoch 22  loss 0.3210  lr 1.78e-04
#  GT: බලපෑම්කරතිබේ.
#  PR: බලපෑම්කරතිබේ
# --------------------------------------------------
# Epoch 23  loss 0.2961  lr 1.69e-04
#  GT: සිටීමටඉඩක්නොදීමිත්රපාක්‌ෂිකයන්ටභාරදීමේ
#  PR: සිමටඉඩමිත්රපාක්‌ෂිකයන්ටභාරදී
# --------------------------------------------------
# Epoch 24  loss 0.2667  lr 1.59e-04
#  GT: යනුවෙනි.
#  PR: යනුවෙ
# --------------------------------------------------
# Epoch 25  loss 0.2395  lr 1.50e-04
#  GT: ප්රයෝජනයපිණිසයයන්නබටහිරදර්ශනයය.
#  PR: ප්රයෝජනයපිණිසයයන්නබටහිරදර්ශනයය
# --------------------------------------------------
# Epoch 26  loss 0.2258  lr 1.41e-04
#  GT: කටයුතුකරනලදි.මිත්රපාක්‌ෂිකයන්ටඑරෙහිවසටන්
#  PR: කටයුතුකරනලදිමිත්රපාක්‌ෂිකයන්ටඑරෙහිවටන්
# --------------------------------------------------
# Epoch 27  loss 0.2058  lr 1.31e-04
#  GT: අමරතුංගමහතාගේපෙබරවාරි10වැනිදාලිපිය
#  PR: අමරතුංගමහතාගේපෙබරවාරි10වැනිදාලිපිය
# --------------------------------------------------
# Epoch 28  loss 0.1862  lr 1.22e-04
#  GT: මතවාදඔවුන්ගේදර්ශනයමතපදනම්වීඇත
#  PR: මතවාදඔවුන්ගේදර්ශනයමතපදනම්වීත
# --------------------------------------------------
# Epoch 29  loss 0.1838  lr 1.13e-04
#  GT: යනුවෙනි.
#  PR: යනුවෙ
# --------------------------------------------------
# Epoch 30  loss 0.1732  lr 1.04e-04
#  GT: කටයුතුකරනලදි.මිත්රපාක්‌ෂිකයන්ටඑරෙහිවසටන්
#  PR: කටයුතුකරනලදි.මිත්රපාක්‌ෂිකයන්ටඑරෙහිවසටන්
# --------------------------------------------------
# Epoch 31  loss 0.1636  lr 9.48e-05
#  GT: ඉතාලිරජයේවිධායකයන්28දෙනකුගෙන්යුතුවූ
#  PR: ඉතාලිරජයේවියකයන්8දෙනකුගෙන්යුතු
# --------------------------------------------------
# Epoch 32  loss 0.1496  lr 8.61e-05
#  GT: සිටීමටඉඩක්නොදීමිත්රපාක්‌ෂිකයන්ටභාරදීමේ
#  PR: සිටීමටඉඩක්දීමිත්රපාක්‌ෂිකයන්ටභාරදීමේ
# --------------------------------------------------
# Epoch 33  loss 0.1382  lr 7.77e-05
#  GT: යටතටපත්කෙරිණ.එසේමඔහුටහිට්‌ලර්සමඟඑකට
#  PR: යටතටපත්කෙරිණ.එසේමඔහුටහිට්‌ලර්සමඟඑකට
# --------------------------------------------------
# Epoch 34  loss 0.1368  lr 6.96e-05
#  GT: ග්රෑන්ඩ්කවුන්සිලයේනිගමනයන්ටඅනුව1943දීජුලි
#  PR: ග්රෑන්ඩ්කවුන්සිලයේනිගමනයන්ටඅනුව1943දීජුලි
# --------------------------------------------------
# Epoch 35  loss 0.1333  lr 6.18e-05
#  GT: බටහිරමතවාදයකි.අමරතුංගමහතාගේඅවුල්අදහස්
#  PR: බටහිරමතවාදයකි.අමරතුංගමහතාගේඅවුල්අදහස්
# --------------------------------------------------
# Epoch 36  loss 0.1204  lr 5.44e-05
#  GT: ලැබෙයි.එහිඅමරතුංගමහතාකියාඇත්තේබටහිර
#  PR: ලැබෙයි.එහිඅමරතුංගමහතාකියාඇත්තේබටහිර
# --------------------------------------------------
# Epoch 37  loss 0.1232  lr 4.73e-05
#  GT: බලපෑම්කරතිබේ.
#  PR: බලපෑම්කරතිබේ
# --------------------------------------------------
# Epoch 38  loss 0.1158  lr 4.07e-05
#  GT: ඉතාලිරජයේවිධායකයන්28දෙනකුගෙන්යුතුවූ
#  PR: ඉතාලිරජයේවියකයන්28දෙනකුගෙන්යුතු
# --------------------------------------------------
# Epoch 39  loss 0.1091  lr 3.44e-05
#  GT: බලපෑම්කරතිබේ.
#  PR: බලපෑම්කරතිබේ.
# --------------------------------------------------
# Epoch 40  loss 0.1063  lr 2.86e-05
#  GT: නමුත්හිට්‌ලර්,මුසෝලෝනීසොයාගෙනඋතුරුඉතාලියේ
#  PR: නමුත්හිට්‌ලර්මුසෝලෝනීසොයාගෙනඋතුරුඉතාලියේ
# --------------------------------------------------
# Epoch 41  loss 0.1014  lr 2.34e-05
#  GT: මතවාදඔවුන්ගේදර්ශනයමතපදනම්වීඇත
#  PR: මතවාදඔවුන්ගේදර්ශනයමතපදනම්වීඇත
# --------------------------------------------------
# Epoch 42  loss 0.1076  lr 1.86e-05
#  GT: බටහිරමතවාදයකි.අමරතුංගමහතාගේඅවුල්අදහස්
#  PR: බටහිරමතවාදයකි.අමරතුංගමහතාගේඅවුල්අදහස්
# --------------------------------------------------
# Epoch 43  loss 0.1025  lr 1.43e-05
#  GT: යටතටපත්කෙරිණ.එසේමඔහුටහිට්‌ලර්සමඟඑකට
#  PR: යටතටපත්කෙරිණ.එසේමඔහුටහිට්‌ලර්සමඟඑකට
# --------------------------------------------------
# Epoch 44  loss 0.1042  lr 1.05e-05
#  GT: ඉතාලිරජයේවිධායකයන්28දෙනකුගෙන්යුතුවූ
#  PR: ඉතාලිරජයේවියකයන්28දෙනකුගෙන්යුතු
# --------------------------------------------------
# Epoch 45  loss 0.1051  lr 7.34e-06
#  GT: ගැනදන්නාඅයකුඒමගහැරයෑමටහෝතමාටවිෂය
#  PR: ගැනදන්නාඅයකුඒමගහැරයෑමටහෝතමාටවිෂය
# --------------------------------------------------
# Epoch 46  loss 0.0987  lr 4.71e-06
#  GT: 25දිනඔහුවපදවියෙන්පහකරරාජ්යබලයහමුදාව
#  PR: 25දිනඔහුවපදවියෙන්පහකරරාජ්යබලයහමුදාව
# --------------------------------------------------
# Epoch 47  loss 0.0983  lr 2.66e-06
#  GT: සිටීමටඉඩක්නොදීමිත්රපාක්‌ෂිකයන්ටභාරදීමේ
#  PR: සිටීමටඉඩක්නොදීමිත්රපාක්‌ෂිකයන්ටභාරදීමේ
# --------------------------------------------------
# Epoch 48  loss 0.1079  lr 1.18e-06
#  GT: අගමැතිතනතුරින්පහකළයුතුබවටතීන්දුවූයේය.
#  PR: අගමැතිතනතුරින්පහකළයුතුබවටතීන්දුවූයේය.
# --------------------------------------------------
# Epoch 49  loss 0.0985  lr 2.96e-07
#  GT: ප්රයෝජනයපිණිසයයන්නබටහිරදර්ශනයය.
#  PR: ප්රයෝජනයපිණිසයයන්නබටහිරදර්ශනයය
# --------------------------------------------------
# Epoch 50  loss 0.1026  lr 0.00e+00
#  GT: ලැබෙයි.එහිඅමරතුංගමහතාකියාඇත්තේබටහිර
#  PR: ලැබෙයි.එහිඅමරතුංගමහතාකියාඇත්තේබටහිර
# --------------------------------------------------

# %%
# ───────── Sinhala OCR – **Inference / Evaluation notebook cell** ──────────
#
# 1.  Point CHECKPOINT, CHARS_TXT, and IMG_DIR / LABELS_JSON to your files.
# 2.  Run this single cell – it loads the model, runs greedy CTC decoding
#     on every image in the JSON, prints the first 10, and reports CER.
# --------------------------------------------------------------------------
import json, regex, random
from pathlib import Path
from PIL import Image
import torch, torch.nn as nn, torch.nn.functional as F
from torch.nn import CTCLoss, TransformerEncoder, TransformerEncoderLayer
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as T
import torchvision.models as models
try:
    import editdistance                       # pip install editdistance
except ImportError:
    raise RuntimeError("pip install editdistance")

# ─── 1. FILES ────────────────────────────────────────────────────────────────
CHECKPOINT  = Path(r"d:/python/checkpoints/sinhala_ocr_epoch50.pt")
CHARS_TXT   = Path(r"d:/python/data/line_crops/chars.txt")
LABELS_JSON = Path(r"d:/python/data/line_crops/labels.json")
IMG_DIR     = Path(r"d:/python/data/line_crops")
# ─── 2. REBUILD CHARSET MAPPINGS ─────────────────────────────────────────────
charset   = [ln.rstrip("\n") for ln in CHARS_TXT.open(encoding="utf-8") if ln.strip()]
char2idx  = {c:i+1 for i,c in enumerate(charset)}    # 0 = blank
idx2char  = {i:c for c,i in char2idx.items()}
blank_idx = 0
# grapheme-cluster splitter
cluster_re = regex.compile(r"\X", regex.UNICODE)
def clusters(s): return [c for c in cluster_re.findall(s) if not c.isspace()]

# ─── 3. LOAD TEST SET (here we just reuse the same JSON) ────────────────────
with LABELS_JSON.open(encoding="utf-8") as f:
    line_map = json.load(f)

t_paths, t_labels = [], []
for fname, txt in line_map.items():
    fp = IMG_DIR / fname
    if not fp.exists(): continue
    cl = clusters(txt)
    if any(c not in char2idx for c in cl): continue
    t_paths.append(str(fp)); t_labels.append(cl)

# ─── 4. DATASET / DATALOADER (*) no augmentation ────────────────────────────
class TestDS(Dataset):
    tfm = T.Compose([
        T.Grayscale(num_output_channels=3),
        T.Resize((32,512), antialias=True),
        T.ToTensor(),
        T.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225]),
    ])
    def __init__(self, paths, lbls): self.p,self.l=paths,lbls
    def __len__(self): return len(self.p)
    def __getitem__(self,i):
        img = self.tfm(Image.open(self.p[i]).convert("RGB"))
        tgt = torch.tensor([char2idx[c] for c in self.l[i]], dtype=torch.long)
        return img, tgt
def collate(b): imgs,lbls=zip(*b); return torch.stack(imgs,0), list(lbls)
loader = DataLoader(TestDS(t_paths,t_labels), batch_size=4,
                    shuffle=False, num_workers=0, collate_fn=collate)

# ─── 5. MODEL  (must mirror training definition) ────────────────────────────
class OCRModel(nn.Module):
    def __init__(self, n):
        super().__init__()
        base = models.resnet18(weights=None)              # weights None: we’ll load
        base.conv1.stride, base.maxpool = (1,1), nn.Identity()
        self.cnn = nn.Sequential(*list(base.children())[:-2])
        self.tcn = nn.Conv1d(512,256,3,1,1,groups=4)
        enc = TransformerEncoderLayer(256,4,512)
        self.tr = TransformerEncoder(enc, 2)
        self.head = nn.Linear(256, n+1)
    def forward(self,x):
        f = self.cnn(x)
        f = F.adaptive_avg_pool2d(f,(1,64)).squeeze(2)
        f = self.tcn(f)
        h = self.tr(f.permute(2,0,1))
        return F.log_softmax(self.head(h),2)              # (T,B,C)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model  = OCRModel(len(charset)).to(device)
ckpt   = torch.load(CHECKPOINT, map_location=device)
model.load_state_dict(ckpt["model_state"]); model.eval()

# ─── 6. GREEDY DECODER ───────────────────────────────────────────────────────
def greedy_decode(logp):                   # logp (T,C)
    arg = torch.argmax(logp,1).cpu().tolist()
    out, prev = [], blank_idx
    for a in arg:
        if a!=prev and a!=blank_idx: out.append(idx2char[a])
        prev = a
    return "".join(out)

# ─── 7. EVALUATION ───────────────────────────────────────────────────────────
tot_cer, seen = 0.0, 0
for imgs, lbls in loader:
    imgs = imgs.to(device)
    with torch.no_grad():
        logp = model(imgs)                 # (T,B,C)
    for b in range(imgs.size(0)):
        pred = greedy_decode(logp[:,b,:])
        gt   = "".join(idx2char[i.item()] for i in lbls[b])
        cer  = editdistance.eval(pred, gt) / max(1,len(gt))
        tot_cer += cer; seen += 1
        if seen <= 10:                     # show first 10 examples
            print(f"GT:   {gt}\nPR:   {pred}\nCER:  {cer:.3f}\n{'-'*50}")

print(f"\nAverage CER over {seen} samples: {tot_cer/seen:.4f}")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24856\3117279397.py:84: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt   = torch.load(CHECKPOINT, map_location=device)
# GT:   අපපෘතුවිවායුගෝලයේඉහලස්තරකීපයක්
# PR:   අපපෘතුවිවායුගෝලයේඉහලස්තරකීපයක්
# CER:  0.000
# --------------------------------------------------
# GT:   තිබේ.පොලවටකිලෝමීටර්40කටවඩාඑපිටින්ඇති
# PR:   තිබේ.පොලවටකිලෝමීටර්40කටවඩාඑපිටින්ඇති
# CER:  0.000
# --------------------------------------------------
# GT:   මෙමස්තරයඅයනගෝලයලෙසහැදින්වේ.
# PR:   මෙමස්තරයඅයනගෝලයලෙසහැදින්වේ.
# CER:  0.000
# --------------------------------------------------
# GT:   අමරතුංගමහතාගේපෙබරවාරි10වැනිදාලිපිය
# PR:   අමරතුංගමහතාගේපෙබරවාරි10වැනිදාලිපිය
# CER:  0.000
# --------------------------------------------------
# GT:   අනුවදෙවියන්වහන්සේවිශ්වයමවාඇත්තේමිනිසාගේ
# PR:   අනුවදෙවියන්වහන්සේවිශ්වයමවාඇත්තේමිනිසාගේ
# CER:  0.000
# --------------------------------------------------
# GT:   ප්රයෝජනයපිණිසයයන්නබටහිරදර්ශනයය.
# PR:   ප්රයෝජනයපිණිසයයන්නබටහිරදර්ශනයය.
# CER:  0.000
# --------------------------------------------------
# GT:   එහෙත්පෙබරවාරි17වැනිදාලිපියටඅනුවඒ
# PR:   එහෙත්පෙබරවාරි17වැනිදාලිපියටඅනුව
# CER:  0.031
# --------------------------------------------------
# GT:   බටහිරමතවාදයකි.අමරතුංගමහතාගේඅවුල්අදහස්
# PR:   බටහිරමතවාදයකි.අමරතුංගමහතාගේඅවුල්අදහස්
# CER:  0.000
# --------------------------------------------------
# GT:   ගැනදන්නාඅයකුඒමගහැරයෑමටහෝතමාටවිෂය
# PR:   ගැනදන්නාඅයකුඒමගහැරයෑමටහෝතමාටවිෂය
# CER:  0.000
# --------------------------------------------------
# GT:   වනඅයුරින්තේරුම්ගැනීමටහෝඋත්සාහකළද
# PR:   වනඅයුරින්තේරුම්ගැනීමටහෝඋත්සාහකළද
# CER:  0.000
# --------------------------------------------------
#
# Average CER over 28 samples: 0.0194

# %% [markdown]
# 2nd way which is more suitable for a research

# %%
import os
import json
import random
import regex                                # pip install regex
from pathlib import Path
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import CTCLoss, TransformerEncoder, TransformerEncoderLayer
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T
import torchvision.models as models
import editdistance                          # pip install editdistance

# -----------------------------------------------------------------------------
# 1) Grapheme cluster utilities & label loading
cluster_re = regex.compile(r"\X", flags=regex.UNICODE)
def get_clusters(s: str) -> list[str]:
    return [c for c in cluster_re.findall(s) if not c.isspace()]

# load JSON: filename → sentence
json_path = Path("d:/python/data/line_crops/labels.json")
with open(json_path, encoding="utf-8") as f:
    line_map = json.load(f)

# build charset
all_clusters = set()
for txt in line_map.values():
    all_clusters.update(get_clusters(txt))
charset  = sorted(all_clusters)
char2idx = {c:i for i,c in enumerate(charset)}
idx2char = {i:c for c,i in char2idx.items()}
blank_idx = len(char2idx)

# collect image paths & labels
img_dir   = Path("d:/python/data/line_crops")
img_paths, labels = [], []
for fname, txt in line_map.items():
    p = img_dir/fname
    if not p.exists(): continue
    cls = get_clusters(txt)
    if cls:
        img_paths.append(str(p))
        labels.append(cls)

# -----------------------------------------------------------------------------
# 2) Dataset classes
class LineDataset(Dataset):
    """For RotNet self-supervision (no labels)."""
    def __init__(self, img_paths, img_size=(512,512)):
        self.paths = img_paths
        self.tf    = T.Compose([
            T.Grayscale(num_output_channels=3),
            T.Resize(img_size),
            T.ToTensor(),
            T.Normalize([0.5]*3, [0.5]*3)
        ])
    def __len__(self):
        return len(self.paths)
    def __getitem__(self, i):
        img = Image.open(self.paths[i]).convert("RGB")
        return self.tf(img)

class OCRDataset(Dataset):
    """Line-level OCR data: image + grapheme-cluster labels."""
    def __init__(self, img_paths, labels, char2idx, img_size=(512,512), augment=False):
        self.paths = img_paths
        self.lbls  = labels
        self.c2i   = char2idx
        self.aug   = augment
        self.base  = T.Compose([
            T.Grayscale(num_output_channels=3),
            T.Resize(img_size),
            T.ToTensor(),
            T.Normalize([0.5]*3, [0.5]*3)
        ])
        self.aug_tf = T.Compose([
            T.RandomRotation(2),
            T.ColorJitter(brightness=0.1, contrast=0.1)
        ])
    def __len__(self):
        return len(self.paths)
    def __getitem__(self, i):
        img = Image.open(self.paths[i]).convert("RGB")
        if self.aug and random.random()<0.5:
            img = self.aug_tf(img)
        img = self.base(img)
        lbl = torch.tensor([self.c2i[c] for c in self.lbls[i]], dtype=torch.long)
        return img, lbl

def ocr_collate(batch):
    return batch  # keep variable-length labels

# -----------------------------------------------------------------------------
# 3) Model definitions
class RotNet(nn.Module):
    def __init__(self):
        super().__init__()
        base = models.resnet18(pretrained=False)
        # make grayscale→3 channel conv, no downsample in conv1/pool
        base.conv1 = nn.Conv2d(3,64,7,1,3,bias=False)
        base.maxpool = nn.Identity()
        self.features = nn.Sequential(*list(base.children())[:-2])
        self.pool     = nn.AdaptiveAvgPool2d(1)
        self.head     = nn.Linear(base.fc.in_features, 4)
    def forward(self, x):
        f = self.features(x)
        f = self.pool(f).view(x.size(0), -1)
        return self.head(f)

class OCRModel(nn.Module):
    def __init__(self, num_chars):
        super().__init__()
        base = models.resnet18(pretrained=False)
        base.conv1   = nn.Conv2d(3,64,7,1,3,bias=False)
        base.maxpool = nn.Identity()
        self.cnn     = nn.Sequential(*list(base.children())[:-2])
        self.tcn     = nn.Conv1d(512,256,3,padding=1,groups=4)
        enc_layer     = TransformerEncoderLayer(d_model=256, nhead=4, dim_feedforward=512)
        self.transformer = TransformerEncoder(enc_layer, num_layers=2)
        self.fc      = nn.Linear(256, num_chars+1)  # +1 blank
    def forward(self, x):
        f   = self.cnn(x)             # (B,512,H',W')
        f   = f.mean(2)               # (B,512,W')
        f   = self.tcn(f)             # (B,256,W')
        seq = f.permute(2,0,1)        # (W',B,256)
        out = self.transformer(seq)   # (W',B,256)
        return F.log_softmax(self.fc(out), dim=2)

# -----------------------------------------------------------------------------
# 4) Pretraining RotNet
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
rotnet = RotNet().to(device)
optim_r = torch.optim.Adam(rotnet.parameters(), lr=2e-4)
crit_r  = nn.CrossEntropyLoss()
ds_r    = LineDataset(img_paths); loader_r = DataLoader(ds_r, batch_size=16, shuffle=True)

for epoch in range(5):
    rotnet.train(); total=0
    for imgs in loader_r:
        imgs = imgs.to(device)
        # random rotate
        R = torch.randint(0,4,(imgs.size(0),), device=device)
        imgs_r = torch.rot90(imgs, k=R, dims=(2,3))
        logits = rotnet(imgs_r)
        loss   = crit_r(logits, R)
        optim_r.zero_grad(); loss.backward(); optim_r.step()
        total += loss.item()
    print(f"RotNet Epoch {epoch+1} loss: {total/len(loader_r):.4f}")

# -----------------------------------------------------------------------------
# 5) OCR training
ocr = OCRModel(num_chars=len(char2idx)).to(device)
# transfer pretrained features
ocr.cnn.load_state_dict(rotnet.features.state_dict(), strict=False)

optim_o = torch.optim.Adam(ocr.parameters(), lr=1e-4)
ctc     = CTCLoss(blank=blank_idx, zero_infinity=False)
ds_o    = OCRDataset(img_paths, labels, char2idx, augment=True)
loader_o= DataLoader(ds_o, batch_size=2, shuffle=True, collate_fn=ocr_collate)
epochs  = 20

for ep in range(1, epochs+1):
    ocr.train(); tot=0
    for batch in loader_o:
        img, lbl = batch[0]
        img = img.unsqueeze(0).to(device)
        L   = lbl.size(0)
        logp= ocr(img)                     # (T,1,C)
        T_l = logp.size(0)
        inp = torch.full((1,), T_l, dtype=torch.long)
        tgt = torch.tensor([L], dtype=torch.long)
        loss= ctc(logp, lbl.unsqueeze(0).to(device), inp, tgt)
        optim_o.zero_grad(); loss.backward(); optim_o.step()
        tot += loss.item()
    print(f"OCR Epoch {ep} avg loss: {tot/len(loader_o):.4f}")

# -----------------------------------------------------------------------------
# 6) Evaluation (greedy CTC + CER)
def greedy_decode(lp: torch.Tensor) -> str:
    arg = lp.argmax(1).cpu().tolist()
    res, prev = [], blank_idx
    for a in arg:
        if a!=prev and a!=blank_idx:
            res.append(idx2char[a])
        prev = a
    return "".join(res)

ocr.eval(); total_cer=0
with torch.no_grad():
    for i,(img,lbl) in enumerate(ds_o):
        lp = ocr(img.unsqueeze(0).to(device)).squeeze(1)
        pred = greedy_decode(lp)
        truth= "".join(lbl.tolist() and [idx2char[x] for x in lbl.tolist()])
        cer = editdistance.eval(pred, truth)/max(1,len(truth))
        total_cer += cer
        if i<5:
            print(f"GT:   {truth}")
            print(f"PRED: {pred}, CER={cer:.3f}\n")
print(f"Overall CER: {total_cer/len(ds_o):.3f}")
